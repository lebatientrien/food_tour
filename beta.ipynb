# %%
# BACKTEST VERSION 2.0 ========================================================
# Apply market indicators and basic commonality analysis
# to detect bottom and trigger the buying time via Telegram
# also perform back-testing record -> Save to Picture
# =============================================================================
# Library for process Datetime
from datetime import datetime, timedelta
import time
import pytz
# Library for POST GET requests
import requests
import urllib.parse
import json
# Library for Data Analysis
# from decimal import Decimal
import pandas as pd
import statistics
import matplotlib
matplotlib.use('Agg')  # Use the Agg backend for non-interactive plotting
import matplotlib.pyplot as plt
# import matplotlib.dates as mdates
import os
# Connect to mariaDB to perform CRUD
import mariadb

# Define the GMT+7 timezone
timezone = pytz.timezone('Asia/Bangkok')
# Set the interval for the status message (in seconds)
interval = 60*60  # 1 hours in seconds
# Check point of important handling - in UNIX timestamp
check_point = time.time()

# Define classification threshold for backtesting
threshold = 0.8

# Database connection parameters
conn_params= {
    "host" : "103.173.66.235",
    # "host" : "localhost",
    "database" : "crypto",
    "user" : "root",
    "password" : "Trien825590"
}
# Define your quiet hours not to send Telegram
quiet_hours = [
    ((22,0),(23,59)),  # 10 PM to midnight
    ((0,0),(6,0))      # Midnight to 6 AM
]

# Function to send a message to Telegram
def send_telegram(message_string, max_retry=2):
    # Telegram bot token and chat ID
    TOKEN = "5614737400:AAHbvZrJbomt09EkpPuhadBCJl7NaGu6rlg"
    ID = "5559031253"

    # Check if the time now is quiet hour or not
    current_time = datetime.now(timezone)
    for start, end in quiet_hours:
        quiet_start = current_time.replace(hour=start[0], minute=start[1], second=0, microsecond=0)
        quiet_end = current_time.replace(hour=end[0], minute=end[1], second=59, microsecond=0)
        if quiet_start <= current_time <= quiet_end:
            return False
    # Then continue process send to Telegram
    current_retry = 0
    while (current_retry <= max_retry):
        date_time = datetime.now(timezone).strftime('%Y-%m-%d %H:%M:%S')
        if current_retry > 0:
            print(f"{date_time} Telegram: Retry #{current_retry}")
            time.sleep(5)   # Wait a second to stabilize the server
        try:
            # URL encode the message string
            encoded_message = urllib.parse.quote(message_string)
            # Construct the URL
            url = f"https://api.telegram.org/bot{TOKEN}/sendMessage?chat_id={ID}&text={encoded_message}"
            # Send the request
            response = requests.post(url, timeout=5)
            response.raise_for_status()
            return True
        except requests.exceptions.RequestException as e:            
            print(date_time, f"ERROR send Telegram: \n{e}")
            current_retry += 1
            if current_retry > max_retry:
                print(date_time, "TELEGRAM: Max retries reached.")
                return False
        except requests.exceptions.HTTPError as http_err:
            print(f"Telegram HTTP error occurred: {http_err}")  # Handle the HTTP error
        except Exception as err:
            print(f"Telegram other error occurred: {err}")      # Handle any other errors

# Function get price 1m, 3m, 5m, 15m, 30m, 1h, 2h, 4h, 6h, 12h, 1d
def get_data(coin_name, time_unit, time_range, max_retry=5, time_out=10):
    current_retry = 0
    url = "https://api-pro.goonus.io/perpetual/v1/klines"
    # Get the current Unix timestamp value in ms
    current_time = int(time.time()) * 1000
    # Define the parameters for the API request
    params = {
        "symbol": coin_name,
        "interval": time_unit,
        "endTime": current_time,
        # "limit": "600"
    }
    headers = {
        "Content-Type": "application/json",
        "Connection": "keep-alive"
    }
    while current_retry <= max_retry:
        if current_retry > 0:
            print(f"GET Crypto {coin_name}: Retry #{current_retry}")
            time.sleep(5)   # Wait a second to stabilize the server
        try:
            # Try request & get the Response during 5 seconds
            response = requests.get(url, params=params, headers=headers, timeout=time_out)
            # Raise an HTTPError for bad responses (4xx and 5xx)
            response.raise_for_status()

            historical_data = response.json()
            # Map the time_range matching with the total record
            while len(historical_data) < time_range:
                time_range -= 10
            # Check if the data has sufficient 100 records
            if len(historical_data) >= 100:
                # Take the latest "time_range" elements in the list
                historical_data = historical_data[-time_range:]
                # [Time,Open,High,Low,Close,Base qty,Quote qty,Time]
                # Filter to only include 'timestamp' and 'close'
                filtered_data = [[
                    # Convert Unix timestamp -> GMT +7 hours (+25200)
                    datetime.fromtimestamp(int(item[0])/1000, tz=pytz.utc).astimezone(timezone).strftime('%Y-%m-%d %H:%M:%S'),
                    # Close price
                    float(item[4]),
                    # Percentage difference
                    round(100*(float(item[2])-float(item[3]))/float(item[1]),2),
                    float(item[2]), float(item[3])
                ] for item in historical_data]
                # [timestamp, close, %price_diff, Highest, Lowest]
                # print(filtered_data)
                return filtered_data
            else:
                date_time = datetime.now(timezone).strftime('%Y-%m-%d %H:%M:%S')
                message = f"Error get {coin_name} - Not enough data ({len(historical_data)})"
                print(date_time, message)
                send_telegram(message)
                return None
        except requests.exceptions.RequestException as e:
            date_time = datetime.now(timezone).strftime('%Y-%m-%d %H:%M:%S')
            print(date_time, f"ERROR Request {coin_name} - retry #{current_retry}\n{e}")
            current_retry += 1
            if current_retry > max_retry:
                print(f"{date_time}: Max retries reached. Raising exception.")
                send_telegram(f"ERROR get: {coin_name} - Max retries\n{e}")
                return None
        except requests.exceptions.HTTPError as http_err:
            print(f"Get crypto HTTP error occurred: {http_err}")  # Handle the HTTP error
        except Exception as err:
            print(f"Get crypto other error occurred: {err}")      # Handle any other errors

# Function to Read empty record in MariaDB database
def read_database(null_data = "yes", max_retry=5):
    current_retry = 0
    while current_retry <= max_retry:
        date_time = datetime.now(timezone).strftime('%Y-%m-%d %H:%M:%S')
        if current_retry > 0:
            print(f"{date_time} READ DB Retry #{current_retry}")
            time.sleep(5)

        # Create connection & implement cursor
        connection = mariadb.connect(**conn_params)
        cursor = connection.cursor()

        try:            
            # Check the null data
            query = "SELECT * FROM `crypto_backtest` ORDER BY `record_id` ASC"
            if null_data == "yes":
                query = "SELECT * FROM `crypto_backtest` WHERE `avg_next30` IS NULL OR `avg_next30` = '' ORDER BY `record_id` ASC"
            elif null_data == "no":
                query = "SELECT * FROM `crypto_backtest` WHERE `avg_next30` IS NOT NULL OR `avg_next30` != '' ORDER BY `record_id` ASC"
            
            cursor.execute(query)
            rows = cursor.fetchall()
            # Close Connection & Free resources
            cursor.close()
            connection.close()
            return rows
        except Exception as e:
            print(f"{date_time}: READ DB failed\n{e}")
            send_telegram(f"READ DB failed #{current_retry}\n{e}")
            current_retry += 1
            if current_retry > max_retry:
                print(f"{date_time}: READ DB Max retries reached.")
                send_telegram(f"READ DB: Max retries reached.")
                # Close Connection & Free resources
                cursor.close()
                connection.close()
                return None

# Function to Delete expire record in MariaDB database
def delete_database(coin_name, date_trigger, max_retry=5):
    current_retry = 0
    while current_retry <= max_retry:
        date_time = datetime.now(timezone).strftime('%Y-%m-%d %H:%M:%S')
        if current_retry > 0:
            print(f"{date_time} DELETE DB Retry #{current_retry}")
            time.sleep(5)

        # Create connection & implement cursor
        connection = mariadb.connect(**conn_params)
        cursor = connection.cursor()

        try:            
            # Check if record exist
            query = "SELECT * FROM `crypto_backtest` WHERE coin_name = ? AND date_trigger = ?"
            data = (coin_name, date_trigger)
            cursor.execute(query,data)
            if len(cursor.fetchall()) > 0:                
                query = "DELETE FROM `crypto_backtest` WHERE coin_name = ? AND date_trigger = ?"
                data = (coin_name, date_trigger)
                cursor.execute(query, data)
                connection.commit()
                # Close Connection & Free resources
                cursor.close()
                connection.close()
                print("\t\tSuccessfully delete record")
                return True
            else:
                print("\t\tCannot find the record to delete")
                # Close Connection & Free resources
                cursor.close()
                connection.close()
                return False

        except Exception as e:
            print(f"{date_time}: DELETE DB failed\n{e}")
            send_telegram(f"DELETE DB failed #{current_retry}\n{e}")
            current_retry += 1
            if current_retry > max_retry:
                print(f"{date_time}: DELETE DB Max retries reached.")
                send_telegram(f"DELETE DB: Max retries reached.")
                # Close Connection & Free resources
                cursor.close()
                connection.close()
                return False

# Function call API to Update in mySQL database ===============================
def update_database(coin_name, date_trigger,
                    avg_next15, min_next15, max_next15,
                    avg_next30, min_next30, max_next30,
                    avg_next45, min_next45, max_next45,
                    avg15_per, min15_per, max15_per,
                    avg30_per, min30_per, max30_per,
                    avg45_per, min45_per, max45_per,
                    result_15, result_30, result_45, max_retry=5):
   
    current_retry = 0
    while current_retry <= max_retry:
        date_time = datetime.now(timezone).strftime('%Y-%m-%d %H:%M:%S')
        if current_retry > 0:
            print(f"{date_time} UPDATE DB Retry #{current_retry}")
            time.sleep(5)

        # Create connection & implement cursor
        connection = mariadb.connect(**conn_params)
        cursor = connection.cursor()

        try:            
            # Check if record exist
            query = "SELECT * FROM `crypto_backtest` WHERE coin_name = ? AND date_trigger = ?"
            data = (coin_name, date_trigger)
            cursor.execute(query,data)
            if len(cursor.fetchall()) > 0:
                query = "UPDATE `crypto_backtest` SET `avg_next15` = ?, `min_next15` = ?, `max_next15` = ?, `avg_next30` = ?, `min_next30` = ?, `max_next30` = ?, `avg_next45` = ?, `min_next45` = ?, `max_next45` = ?,\
                        `avg15_per` = ?, `min15_per` = ?, `max15_per` = ?, `avg30_per` = ?, `min30_per` = ?, `max30_per` = ?, `avg45_per` = ?, `min45_per` = ?, `max45_per` = ?,\
                        `result_15` = ?, `result_30` = ?, `result_45` = ? WHERE `crypto_backtest`.`coin_name` = ? AND `crypto_backtest`.`date_trigger` = ?"
                data = (    avg_next15, min_next15, max_next15, avg_next30, min_next30, max_next30, avg_next45, min_next45, max_next45,
                            avg15_per, min15_per, max15_per, avg30_per, min30_per, max30_per, avg45_per, min45_per, max45_per,
                            result_15, result_30, result_45, coin_name, date_trigger)
                cursor.execute(query, data)
                connection.commit()
                # Close Connection & Free resources
                cursor.close()
                connection.close()
                print(f"\t\t{coin_name}: Successfully update record")
                return True
            else:
                print("\t\tCannot find the record to update")
                # Close Connection & Free resources
                cursor.close()
                connection.close()
                return False

        except Exception as e:            
            print(f"{date_time}: UPDATE DB failed\n{e}")
            send_telegram(f"UPDATE DB failed #{current_retry}\n{e}")
            current_retry += 1
            if current_retry > max_retry:
                print(f"{date_time}: UPDATE DB Max retries reached.")
                send_telegram(f"UPDAET DB: Max retries reached.")
                # Close Connection & Free resources
                cursor.close()
                connection.close()
                return False

# Process Back testing ========================================================
def back_testing():
    date_time = datetime.now(timezone).strftime('%Y-%m-%d %H:%M:%S')
    print(f"{date_time}: Start Backtesting")

    pending_data = read_database(null_data='yes')
    # print("Pending Data:", len(pending_data), pending_data)j
    
    if pending_data and len(pending_data) > 0:
        print(f"\t\tRemaining {len(pending_data)} record(s)")
        pending_coins = [(item[1], item[3], float(item[4])) for item in pending_data]
        # print("Pending:", pending_coins)
        for remain in pending_coins:
            # [(coin_name, trigger_date, trigger_value)]
            coin_name = remain[0]
            trigger_date = remain[1]
            trigger_value = remain[2]
            
            # Collect data based on each record
            datacoin_backtest = get_data(coin_name, "1m", 600)
            
            # Check if the trigger_date < oldest_date -> Delete record ========================
            oldest_date = datetime.strptime(datacoin_backtest[0][0],'%Y-%m-%d %H:%M:%S')
            # print(oldest_date, trigger_date)
            if (trigger_date <= oldest_date):
                print(f'\t\t{coin_name}: Late record data -> Delete')
                delete_database(coin_name, trigger_date.strftime('%Y-%m-%d %H:%M:%S'))
                continue    # Skip to next record
            
            # Start Performing back Testing ====================================================
            # Calculate the end time (15 minutes after trigger_datetime)
            end_time15 = trigger_date + timedelta(minutes=15)
            end_time30 = trigger_date + timedelta(minutes=30)
            end_time45 = trigger_date + timedelta(minutes=45)
            # print(end_time15, end_time30, end_time45)

            try:
                # Filter out elements that are larger than the trigger_datetime within 15 minutes
                filtered_list15 = [entry for entry in datacoin_backtest if remain[1] < datetime.strptime(entry[0], '%Y-%m-%d %H:%M:%S') <= end_time15]
                filtered_list30 = [entry for entry in datacoin_backtest if remain[1] < datetime.strptime(entry[0], '%Y-%m-%d %H:%M:%S') <= end_time30]
                filtered_list45 = [entry for entry in datacoin_backtest if remain[1] < datetime.strptime(entry[0], '%Y-%m-%d %H:%M:%S') <= end_time45]
                # print(remain, len(filtered_list45))

                # Wait until enough dataset
                if len(filtered_list45) >= 45:
                    # ['timestamp', 'close', 'percent', 'high', 'low']
                    val15_avg = [entry15[1] for entry15 in filtered_list15]
                    val15_min = [entry15[4] for entry15 in filtered_list15]
                    val15_max = [entry15[3] for entry15 in filtered_list15]
                    val30_avg = [entry30[1] for entry30 in filtered_list30]
                    val30_min = [entry30[4] for entry30 in filtered_list30]
                    val30_max = [entry30[3] for entry30 in filtered_list30]
                    val45_avg = [entry45[1] for entry45 in filtered_list45]
                    val45_min = [entry45[4] for entry45 in filtered_list45]
                    val45_max = [entry45[3] for entry45 in filtered_list45]

                    # Calculate in 15
                    avg_value15 = round((statistics.mean(val15_avg) if val15_avg else None), 3)
                    avg15_per = round(100 * (avg_value15 - remain[2]) / remain[2], 3)
                    min_value15 = min(val15_min) if val15_min else None
                    min15_per = round(100 * (min_value15 - remain[2]) / remain[2], 3)
                    max_value15 = max(val15_max) if val15_max else None
                    max15_per = round(100 * (max_value15 - remain[2]) / remain[2], 3)
                    # Compare threshold and Calculate Result 15:
                    res15_avg = 2 if avg15_per >= threshold else 1 if 0 < avg15_per < threshold else -1 if -threshold < avg15_per < 0 else -2 if avg15_per <= -threshold else 0
                    res15_min = 3 if min15_per >= threshold else 2 if 0 < min15_per < threshold else -2 if -threshold < min15_per < 0 else -3 if min15_per <= -threshold else 0
                    res15_max = 4 if max15_per >= threshold else 2 if 0 < max15_per < threshold else -2 if -threshold < max15_per < 0 else -4 if max15_per <= -threshold else 0
                    result_15 = res15_avg + res15_min + res15_max

                    # Calculate in 30
                    avg_value30 = round((statistics.mean(val30_avg) if val30_avg else None), 3)
                    avg30_per = round(100 * (avg_value30 - remain[2]) / remain[2], 3)
                    min_value30 = min(val30_min) if val30_min else None
                    min30_per = round(100 * (min_value30 - remain[2]) / remain[2], 3)
                    max_value30 = max(val30_max) if val30_max else None
                    max30_per = round(100 * (max_value30 - remain[2]) / remain[2], 3)
                    # Compare threshold and Calculate Result 30
                    res30_avg = 2 if avg30_per >= threshold else 1 if 0 < avg30_per < threshold else -1 if -threshold < avg30_per < 0 else -2 if avg30_per <= -threshold else 0
                    res30_min = 3 if min30_per >= threshold else 2 if 0 < min30_per < threshold else -2 if -threshold < min30_per < 0 else -3 if min30_per <= -threshold else 0
                    res30_max = 4 if max30_per >= threshold else 2 if 0 < max30_per < threshold else -2 if -threshold < max30_per < 0 else -4 if max30_per <= -threshold else 0
                    result_30 = res30_avg + res30_min + res30_max

                    # Calculate in 45
                    avg_value45 = round((statistics.mean(val45_avg) if val45_avg else None), 3)
                    avg45_per = round(100 * (avg_value45 - remain[2]) / remain[2], 3)
                    min_value45 = min(val45_min) if val45_min else None
                    min45_per = round(100 * (min_value45 - remain[2]) / remain[2], 3)
                    max_value45 = max(val45_max) if val45_max else None
                    max45_per = round(100 * (max_value45 - remain[2]) / remain[2], 3)
                    # Compare threshold and Calculate Result 45
                    res45_avg = 2 if avg45_per >= threshold else 1 if 0 < avg45_per < threshold else -1 if -threshold < avg45_per < 0 else -2 if avg45_per <= -threshold else 0
                    res45_min = 3 if min45_per >= threshold else 2 if 0 < min45_per < threshold else -2 if -threshold < min45_per < 0 else -3 if min45_per <= -threshold else 0
                    res45_max = 4 if max45_per >= threshold else 2 if 0 < max45_per < threshold else -2 if -threshold < max45_per < 0 else -4 if max45_per <= -threshold else 0
                    result_45 = res45_avg + res45_min + res45_max

                    # Update Database
                    update_database(coin_name, trigger_date.strftime('%Y-%m-%d %H:%M:%S'), avg_value15, min_value15, max_value15, avg_value30, min_value30, max_value30, avg_value45, min_value45, max_value45,
                                    avg15_per, min15_per, max15_per, avg30_per, min30_per, max30_per, avg45_per, min45_per, max45_per, result_15, result_30, result_45)

                    # Draw graph ======================================
                    # Convert to DataFrame
                    df_graph = pd.DataFrame(datacoin_backtest, columns=['timestamp', 'close', 'percent', 'high', 'low'])
                    # Limit to the latest 250 records
                    df_graph = df_graph.tail(250)
                    # Change the "timestamp" to the datetime format
                    df_graph['timestamp'] = pd.to_datetime(df_graph['timestamp'], format='%Y-%m-%d %H:%M:%S', errors='coerce')
                    # Plot the visualization
                    plt.figure(figsize=(8, 4))
                    plt.title(f'"{coin_name}" at "{trigger_date}" - ({res15_avg}+{res15_min}+{res15_max})/({res30_avg}+{res30_min}+{res30_max})/({res45_avg}+{res45_min}+{res45_max})')
                    plt.plot(df_graph['timestamp'], df_graph['close'], label='Close Price', color='blue')
                    # plt.xlabel('Time')
                    # plt.ylabel('Price')
                    plt.axvline(x = trigger_date, color = 'red', linestyle = '--', label = 'Specific Time')
                    plt.axvline(x = end_time15, color = 'black', linestyle = ':')
                    plt.axvline(x = end_time30, color = 'black', linestyle = ':')
                    plt.axvline(x = end_time45, color = 'black', linestyle = ':')
                    plt.legend()
                    plt.grid(True)
                    # # Save the plot as a file C:\Users\lebti\OneDrive - Schaeffler Technologies AG & Co. KG\3_Project\Tyen\food_tour\graph\2024-12-08_12-58-12_BIGTIMEVNDC.png
                    file_name = rf"C:\inetpub\wwwroot\crypto\{trigger_date.strftime('%Y-%m-%d_%H-%M-%S')}_{coin_name}.png"
                    # print(file_name)
                    plt.savefig(file_name, dpi=100)
                    # plt.show()
                    plt.clf()
                    plt.close('all')
                    print(f"\t\t{coin_name}: Successfully generate graph")

                    time.sleep(5)
                    # if os.path.exists(file_name):
                    #     os.remove(file_name)

                elif len(filtered_list45) < 45:
                    print(f'\t\t{coin_name}: Not enough record ({len(filtered_list45)})')

            except Exception as e:
                print(f"BACKTEST ERROR: {e}")
                send_telegram(f"BACKTEST ERROR: {e}")
    else:
        print(" ===> ERROR:", pending_data)

# MAIN PROGRAM ================================================================
if __name__ == '__main__':
    # Send log to Telegram
    date_time = datetime.now(timezone).strftime('%Y-%m-%d %H:%M:%S')
    message = f"{date_time}: Beta started"
    print(message)
    send_telegram(message)

    try:
        # Create connection & implement cursor
        connection = mariadb.connect(**conn_params)
        cursor = connection.cursor()
        # Close Connection & Free resources
        cursor.close()
        connection.close()

        # Infinite loop to execute
        while True:
            back_testing()

            current_time = time.time()
            if (current_time - check_point) >= interval:
                # date_time = datetime.now(timezone).strftime('%Y-%m-%d %H:%M:%S')
                check_point = current_time
                # Process Back Testing
                send_telegram("Beta still working")

            time.sleep(600)
    except KeyboardInterrupt:
        print("Server is shutting down...")
    finally:
        # Close Connection & Free resources
        cursor.close()
        connection.close()

# %%
# Library for process Datetime
from datetime import datetime, timedelta
import time
import pytz
# Library for POST GET requests
import requests
import urllib.parse
import json
# Library for Data Analysis
# from decimal import Decimal
import pandas as pd
import statistics
import matplotlib
matplotlib.use('Agg')  # Use the Agg backend for non-interactive plotting
import matplotlib.pyplot as plt
# import matplotlib.dates as mdates
import os
import shutil
# Connect to mariaDB to perform CRUD
import mariadb


# Define the GMT+7 timezone
timezone = pytz.timezone('Asia/Bangkok')

# Database connection parameters
conn_params= {
    "host" : "103.173.66.235",
    # "host" : "localhost",
    "database" : "crypto",
    "user" : "root",
    "password" : "Trien825590"
}

# Function to Read empty record in MariaDB database
def read_database(null_data = "yes", max_retry=5):
    current_retry = 0
    while current_retry <= max_retry:
        date_time = datetime.now(timezone).strftime('%Y-%m-%d %H:%M:%S')
        if current_retry > 0:
            print(f"{date_time} READ DB Retry #{current_retry}")
            time.sleep(5)

        # Create connection & implement cursor
        connection = mariadb.connect(**conn_params)
        cursor = connection.cursor()

        try:            
            # Check the null data
            query = "SELECT * FROM `crypto_backtest` ORDER BY `record_id` ASC"
            if null_data == "yes":
                query = "SELECT * FROM `crypto_backtest` WHERE `avg_next30` IS NULL OR `avg_next30` = '' ORDER BY `record_id` ASC"
            elif null_data == "no":
                query = "SELECT * FROM `crypto_backtest` WHERE `avg_next30` IS NOT NULL OR `avg_next30` != '' ORDER BY `record_id` ASC"
            
            cursor.execute(query)
            rows = cursor.fetchall()
            # Close Connection & Free resources
            cursor.close()
            connection.close()
            return rows
        except Exception as e:
            print(f"{date_time}: READ DB failed\n{e}")
            send_telegram(f"READ DB failed #{current_retry}\n{e}")
            current_retry += 1
            if current_retry > max_retry:
                print(f"{date_time}: READ DB Max retries reached.")
                send_telegram(f"READ DB: Max retries reached.")
                # Close Connection & Free resources
                cursor.close()
                connection.close()
                return None


data = read_database(null_data='no')
print(len(data))
for i in data:
    # print(i)
    coin_name = i[1]
    date_string = i[3]
    result = int(i[26])
    filename = rf"crypto\{date_string.strftime('%Y-%m-%d_%H-%M-%S')}_{coin_name}.png"
    if os.path.exists(filename):
        if result > 0:
            new_filename = rf"positive\{date_string.strftime('%Y-%m-%d_%H-%M-%S')}_{coin_name}.png"
            shutil.copy(filename, new_filename)
        else:
            new_filename = rf"negative\{date_string.strftime('%Y-%m-%d_%H-%M-%S')}_{coin_name}.png"
            shutil.copy(filename, new_filename)
    else:
        print(filename, "NOT EXITS !")
    # print(filename)
# Out:
# 1460
# crypto\2024-12-08_01-41-16_DOGEVNDC.png NOT EXITS !
# crypto\2024-12-08_01-41-16_DOGEVNDC.png
# crypto\2024-12-08_02-28-03_ADAVNDC.png NOT EXITS !
# crypto\2024-12-08_02-28-03_ADAVNDC.png
# crypto\2024-12-08_02-32-33_UNIVNDC.png NOT EXITS !
# crypto\2024-12-08_02-32-33_UNIVNDC.png
# crypto\2024-12-08_02-37-12_SUIVNDC.png NOT EXITS !
# crypto\2024-12-08_02-37-12_SUIVNDC.png
# crypto\2024-12-08_02-39-10_GRASSVNDC.png NOT EXITS !
# crypto\2024-12-08_02-39-10_GRASSVNDC.png
# crypto\2024-12-08_02-40-07_LYNXVNDC.png NOT EXITS !
# crypto\2024-12-08_02-40-07_LYNXVNDC.png
# crypto\2024-12-08_02-40-09_WLDVNDC.png NOT EXITS !
# crypto\2024-12-08_02-40-09_WLDVNDC.png
# crypto\2024-12-08_02-40-18_SOLVNDC.png NOT EXITS !
# crypto\2024-12-08_02-40-18_SOLVNDC.png
# crypto\2024-12-08_02-40-24_XLMVNDC.png NOT EXITS !
# crypto\2024-12-08_02-40-24_XLMVNDC.png
# crypto\2024-12-08_02-41-16_LISTAVNDC.png NOT EXITS !
# crypto\2024-12-08_02-41-16_LISTAVNDC.png
# crypto\2024-12-08_02-46-53_HBARVNDC.png NOT EXITS !
# crypto\2024-12-08_02-46-53_HBARVNDC.png
# crypto\2024-12-08_02-58-10_CETUSVNDC.png NOT EXITS !
# crypto\2024-12-08_02-58-10_CETUSVNDC.png
# crypto\2024-12-08_03-31-13_MIAVNDC.png NOT EXITS !
# crypto\2024-12-08_03-31-13_MIAVNDC.png
# crypto\2024-12-08_03-35-27_EGPT1000VNDC.png NOT EXITS !
# crypto\2024-12-08_03-35-27_EGPT1000VNDC.png
# crypto\2024-12-08_03-36-07_PEPE1000VNDC.png NOT EXITS !
# crypto\2024-12-08_03-36-07_PEPE1000VNDC.png
# crypto\2024-12-08_03-36-49_MOODENGVNDC.png NOT EXITS !
# crypto\2024-12-08_03-36-49_MOODENGVNDC.png
# crypto\2024-12-08_04-24-08_NEIROVNDC.png NOT EXITS !
# crypto\2024-12-08_04-24-08_NEIROVNDC.png
# crypto\2024-12-08_04-39-08_WIFVNDC.png NOT EXITS !
# crypto\2024-12-08_04-39-08_WIFVNDC.png
# crypto\2024-12-08_04-40-59_EDU3VNDC.png NOT EXITS !
# crypto\2024-12-08_04-40-59_EDU3VNDC.png
# crypto\2024-12-08_04-41-15_EGPT1000VNDC.png NOT EXITS !
# crypto\2024-12-08_04-41-15_EGPT1000VNDC.png
# crypto\2024-12-08_04-41-18_DOGSVNDC.png NOT EXITS !
# crypto\2024-12-08_04-41-18_DOGSVNDC.png
# crypto\2024-12-08_04-42-10_LYNXVNDC.png NOT EXITS !
# crypto\2024-12-08_04-42-10_LYNXVNDC.png
# crypto\2024-12-08_04-42-20_SOLVNDC.png NOT EXITS !
# crypto\2024-12-08_04-42-20_SOLVNDC.png
# crypto\2024-12-08_04-44-13_1000CATVNDC.png NOT EXITS !
# crypto\2024-12-08_04-44-13_1000CATVNDC.png
# crypto\2024-12-08_04-45-24_FOXYVNDC.png NOT EXITS !
# crypto\2024-12-08_04-45-24_FOXYVNDC.png
# crypto\2024-12-08_05-13-09_TIAVNDC.png NOT EXITS !
# crypto\2024-12-08_05-13-09_TIAVNDC.png
# crypto\2024-12-08_05-13-24_DOTVNDC.png NOT EXITS !
# crypto\2024-12-08_05-13-24_DOTVNDC.png
# crypto\2024-12-08_05-14-06_MCAKEVNDC.png NOT EXITS !
# crypto\2024-12-08_05-14-06_MCAKEVNDC.png
# crypto\2024-12-08_05-14-08_EGPT1000VNDC.png NOT EXITS !
# crypto\2024-12-08_05-14-08_EGPT1000VNDC.png
# crypto\2024-12-08_05-14-10_MEON1000VNDC.png NOT EXITS !
# crypto\2024-12-08_05-14-10_MEON1000VNDC.png
# crypto\2024-12-08_05-14-12_DOGSVNDC.png NOT EXITS !
# crypto\2024-12-08_05-14-12_DOGSVNDC.png
# crypto\2024-12-08_05-36-11_EDU3VNDC.png NOT EXITS !
# crypto\2024-12-08_05-36-11_EDU3VNDC.png
# crypto\2024-12-08_05-39-04_PEPE1000VNDC.png NOT EXITS !
# crypto\2024-12-08_05-39-04_PEPE1000VNDC.png
# crypto\2024-12-08_06-04-04_WIFVNDC.png NOT EXITS !
# crypto\2024-12-08_06-04-04_WIFVNDC.png
# crypto\2024-12-08_06-05-52_MCAKEVNDC.png NOT EXITS !
# crypto\2024-12-08_06-05-52_MCAKEVNDC.png
# crypto\2024-12-08_06-05-55_EDU3VNDC.png NOT EXITS !
# crypto\2024-12-08_06-05-55_EDU3VNDC.png
# crypto\2024-12-08_06-05-57_MEON1000VNDC.png NOT EXITS !
# crypto\2024-12-08_06-05-57_MEON1000VNDC.png
# crypto\2024-12-08_06-06-14_MIAVNDC.png NOT EXITS !
# crypto\2024-12-08_06-06-14_MIAVNDC.png
# crypto\2024-12-08_06-07-05_1000CATVNDC.png NOT EXITS !
# crypto\2024-12-08_06-07-05_1000CATVNDC.png
# crypto\2024-12-08_06-26-16_MOODENGVNDC.png NOT EXITS !
# crypto\2024-12-08_06-26-16_MOODENGVNDC.png
# crypto\2024-12-08_06-51-12_FOXYVNDC.png NOT EXITS !
# crypto\2024-12-08_06-51-12_FOXYVNDC.png
# crypto\2024-12-08_07-00-03_BIGTIMEVNDC.png NOT EXITS !
# crypto\2024-12-08_07-00-03_BIGTIMEVNDC.png
# crypto\2024-12-08_07-05-24_TRUVNDC.png NOT EXITS !
# crypto\2024-12-08_07-05-24_TRUVNDC.png
# crypto\2024-12-08_07-13-10_XLMVNDC.png NOT EXITS !
# crypto\2024-12-08_07-13-10_XLMVNDC.png
# crypto\2024-12-08_07-15-01_FOXYVNDC.png NOT EXITS !
# crypto\2024-12-08_07-15-01_FOXYVNDC.png
# crypto\2024-12-08_07-17-00_UXLINKVNDC.png NOT EXITS !
# crypto\2024-12-08_07-17-00_UXLINKVNDC.png
# crypto\2024-12-08_07-18-24_WIFVNDC.png NOT EXITS !
# crypto\2024-12-08_07-18-24_WIFVNDC.png
# crypto\2024-12-08_07-24-49_BIGTIMEVNDC.png NOT EXITS !
# crypto\2024-12-08_07-24-49_BIGTIMEVNDC.png
# crypto\2024-12-08_07-26-14_XRPVNDC.png NOT EXITS !
# crypto\2024-12-08_07-26-14_XRPVNDC.png
# crypto\2024-12-08_07-53-05_NEIROVNDC.png NOT EXITS !
# crypto\2024-12-08_07-53-05_NEIROVNDC.png
# crypto\2024-12-08_07-54-33_TRUVNDC.png NOT EXITS !
# crypto\2024-12-08_07-54-33_TRUVNDC.png
# crypto\2024-12-08_07-56-40_HBARVNDC.png NOT EXITS !
# crypto\2024-12-08_07-56-40_HBARVNDC.png
# crypto\2024-12-08_08-13-11_UNIVNDC.png NOT EXITS !
# crypto\2024-12-08_08-13-11_UNIVNDC.png
# crypto\2024-12-08_08-26-10_WLDVNDC.png NOT EXITS !
# crypto\2024-12-08_08-26-10_WLDVNDC.png
# crypto\2024-12-08_08-29-09_LDOVNDC.png NOT EXITS !
# crypto\2024-12-08_08-29-09_LDOVNDC.png
# crypto\2024-12-08_08-30-09_BIGTIMEVNDC.png NOT EXITS !
# crypto\2024-12-08_08-30-09_BIGTIMEVNDC.png
# crypto\2024-12-08_08-41-06_WIFVNDC.png NOT EXITS !
# crypto\2024-12-08_08-41-06_WIFVNDC.png
# crypto\2024-12-08_08-41-09_ENSVNDC.png NOT EXITS !
# crypto\2024-12-08_08-41-09_ENSVNDC.png
# crypto\2024-12-08_08-43-16_TRUVNDC.png NOT EXITS !
# crypto\2024-12-08_08-43-16_TRUVNDC.png
# crypto\2024-12-08_09-05-34_LISTAVNDC.png NOT EXITS !
# crypto\2024-12-08_09-05-34_LISTAVNDC.png
# crypto\2024-12-08_09-14-02_KSMVNDC.png NOT EXITS !
# crypto\2024-12-08_09-14-02_KSMVNDC.png
# crypto\2024-12-08_09-26-02_XRPVNDC.png NOT EXITS !
# crypto\2024-12-08_09-26-02_XRPVNDC.png
# crypto\2024-12-08_09-39-44_GRASSVNDC.png NOT EXITS !
# crypto\2024-12-08_09-39-44_GRASSVNDC.png
# crypto\2024-12-08_09-40-12_MOODENGVNDC.png NOT EXITS !
# crypto\2024-12-08_09-40-12_MOODENGVNDC.png
# crypto\2024-12-08_09-42-09_MIAVNDC.png NOT EXITS !
# crypto\2024-12-08_09-42-09_MIAVNDC.png
# crypto\2024-12-08_10-12-12_SUIVNDC.png NOT EXITS !
# crypto\2024-12-08_10-12-12_SUIVNDC.png
# crypto\2024-12-08_10-43-32_JASMYVNDC.png NOT EXITS !
# crypto\2024-12-08_10-43-32_JASMYVNDC.png
# crypto\2024-12-08_10-55-09_MOODENGVNDC.png NOT EXITS !
# crypto\2024-12-08_10-55-09_MOODENGVNDC.png
# crypto\2024-12-08_10-56-14_CETUSVNDC.png NOT EXITS !
# crypto\2024-12-08_10-56-14_CETUSVNDC.png
# crypto\2024-12-08_10-56-21_OPVNDC.png NOT EXITS !
# crypto\2024-12-08_10-56-21_OPVNDC.png
# crypto\2024-12-08_10-56-27_PEPE1000VNDC.png NOT EXITS !
# crypto\2024-12-08_10-56-27_PEPE1000VNDC.png
# crypto\2024-12-08_11-03-08_SANDVNDC.png NOT EXITS !
# crypto\2024-12-08_11-03-08_SANDVNDC.png
# crypto\2024-12-08_11-05-33_FOXYVNDC.png NOT EXITS !
# crypto\2024-12-08_11-05-33_FOXYVNDC.png
# crypto\2024-12-08_11-15-33_XRPVNDC.png NOT EXITS !
# crypto\2024-12-08_11-15-33_XRPVNDC.png
# crypto\2024-12-08_11-29-13_UXLINKVNDC.png NOT EXITS !
# crypto\2024-12-08_11-29-13_UXLINKVNDC.png
# crypto\2024-12-08_11-30-55_BIGTIMEVNDC.png NOT EXITS !
# crypto\2024-12-08_11-30-55_BIGTIMEVNDC.png
# crypto\2024-12-08_11-31-22_UXLINKVNDC.png NOT EXITS !
# crypto\2024-12-08_11-31-22_UXLINKVNDC.png
# crypto\2024-12-08_11-31-49_BIGTIMEVNDC.png NOT EXITS !
# crypto\2024-12-08_11-31-49_BIGTIMEVNDC.png
# crypto\2024-12-08_11-32-54_UXLINKVNDC.png NOT EXITS !
# crypto\2024-12-08_11-32-54_UXLINKVNDC.png
# crypto\2024-12-08_11-45-02_WIFVNDC.png NOT EXITS !
# crypto\2024-12-08_11-45-02_WIFVNDC.png
# crypto\2024-12-08_11-46-04_DOGEVNDC.png NOT EXITS !
# crypto\2024-12-08_11-46-04_DOGEVNDC.png
# crypto\2024-12-08_11-46-12_DOTVNDC.png NOT EXITS !
# crypto\2024-12-08_11-46-12_DOTVNDC.png
# crypto\2024-12-08_11-46-16_AVAXVNDC.png NOT EXITS !
# crypto\2024-12-08_11-46-16_AVAXVNDC.png
# crypto\2024-12-08_11-47-02_BIGTIMEVNDC.png NOT EXITS !
# crypto\2024-12-08_11-47-02_BIGTIMEVNDC.png
# crypto\2024-12-08_11-47-09_PEPE1000VNDC.png NOT EXITS !
# crypto\2024-12-08_11-47-09_PEPE1000VNDC.png
# crypto\2024-12-08_11-47-58_GRASSVNDC.png NOT EXITS !
# crypto\2024-12-08_11-47-58_GRASSVNDC.png
# crypto\2024-12-08_12-26-08_XRPVNDC.png NOT EXITS !
# crypto\2024-12-08_12-26-08_XRPVNDC.png
# crypto\2024-12-08_12-53-26_UXLINKVNDC.png NOT EXITS !
# crypto\2024-12-08_12-53-26_UXLINKVNDC.png
# crypto\2024-12-08_12-54-05_NEIROVNDC.png NOT EXITS !
# crypto\2024-12-08_12-54-05_NEIROVNDC.png
# crypto\2024-12-08_12-55-11_1000CATVNDC.png NOT EXITS !
# crypto\2024-12-08_12-55-11_1000CATVNDC.png
# crypto\2024-12-08_12-55-23_KSMVNDC.png NOT EXITS !
# crypto\2024-12-08_12-55-23_KSMVNDC.png
# crypto\2024-12-08_12-55-25_DOTVNDC.png
# crypto\2024-12-08_12-56-04_AVAXVNDC.png
# crypto\2024-12-08_12-56-16_EGPT1000VNDC.png
# crypto\2024-12-08_12-57-07_CKBVNDC.png
# crypto\2024-12-08_12-57-10_MOODENGVNDC.png
# crypto\2024-12-08_12-58-12_BIGTIMEVNDC.png
# crypto\2024-12-08_13-16-08_TIAVNDC.png
# crypto\2024-12-08_13-59-09_HBARVNDC.png
# crypto\2024-12-08_14-32-09_SANDVNDC.png
# crypto\2024-12-08_14-34-20_LINKVNDC.png
# crypto\2024-12-08_14-55-07_BIGTIMEVNDC.png
# crypto\2024-12-08_15-00-20_HBARVNDC.png
# crypto\2024-12-08_15-04-02_JASMYVNDC.png
# crypto\2024-12-08_15-12-04_TIAVNDC.png
# crypto\2024-12-08_15-15-05_LISTAVNDC.png
# crypto\2024-12-08_15-15-19_TRUVNDC.png
# crypto\2024-12-08_15-15-26_WLDVNDC.png
# crypto\2024-12-08_15-15-34_DOGEVNDC.png
# crypto\2024-12-08_15-15-37_SXPVNDC.png
# crypto\2024-12-08_15-23-14_BIGTIMEVNDC.png
# crypto\2024-12-08_15-26-16_DOGSVNDC.png
# crypto\2024-12-08_15-28-10_MCAKEVNDC.png
# crypto\2024-12-08_15-28-14_MEON1000VNDC.png
# crypto\2024-12-08_15-28-17_SUIVNDC.png
# crypto\2024-12-08_15-29-10_WIFVNDC.png
# crypto\2024-12-08_15-47-57_EDU3VNDC.png
# crypto\2024-12-08_16-02-14_UXLINKVNDC.png
# crypto\2024-12-08_16-02-16_MOODENGVNDC.png
# crypto\2024-12-08_16-02-19_MEON1000VNDC.png
# crypto\2024-12-08_16-02-44_HBARVNDC.png
# crypto\2024-12-08_16-03-15_SANDVNDC.png
# crypto\2024-12-08_16-04-15_CETUSVNDC.png
# crypto\2024-12-08_16-04-18_SXPVNDC.png
# crypto\2024-12-08_16-04-21_MIAVNDC.png
# crypto\2024-12-08_16-04-25_TRUVNDC.png
# crypto\2024-12-08_16-04-30_KSMVNDC.png
# crypto\2024-12-08_16-04-33_AVAXVNDC.png
# crypto\2024-12-08_16-04-36_WLDVNDC.png
# crypto\2024-12-08_16-41-57_LINKVNDC.png
# crypto\2024-12-08_17-31-48_AVAXVNDC.png
# crypto\2024-12-08_18-09-07_WLDVNDC.png
# crypto\2024-12-08_19-09-09_NEIROVNDC.png
# crypto\2024-12-08_19-10-12_MOODENGVNDC.png
# crypto\2024-12-08_19-11-04_DOGSVNDC.png
# crypto\2024-12-08_19-11-06_SUIVNDC.png
# crypto\2024-12-08_19-11-09_LINKVNDC.png
# crypto\2024-12-08_19-11-13_DOTVNDC.png
# crypto\2024-12-08_19-11-15_SANDVNDC.png
# crypto\2024-12-08_19-11-18_GRASSVNDC.png
# crypto\2024-12-08_19-11-29_MCAKEVNDC.png
# crypto\2024-12-08_19-11-31_EGPT1000VNDC.png
# crypto\2024-12-08_19-11-35_MEON1000VNDC.png
# crypto\2024-12-08_19-11-42_TIAVNDC.png
# crypto\2024-12-08_19-12-08_CETUSVNDC.png
# crypto\2024-12-08_19-12-25_WLDVNDC.png
# crypto\2024-12-08_19-12-36_EDU3VNDC.png
# crypto\2024-12-08_19-12-40_TRUVNDC.png
# crypto\2024-12-08_19-12-42_OPVNDC.png
# crypto\2024-12-08_19-12-58_MIAVNDC.png
# crypto\2024-12-08_19-41-42_UNIVNDC.png
# crypto\2024-12-08_20-38-16_LINKVNDC.png
# crypto\2024-12-08_20-39-18_UNIVNDC.png
# crypto\2024-12-08_21-10-57_JASMYVNDC.png
# crypto\2024-12-08_21-12-04_DOGEVNDC.png
# crypto\2024-12-08_21-12-08_MIAVNDC.png
# crypto\2024-12-08_21-12-13_1000CATVNDC.png
# crypto\2024-12-08_21-12-20_HBARVNDC.png
# crypto\2024-12-08_21-12-48_FOXYVNDC.png
# crypto\2024-12-08_21-45-10_UNIVNDC.png
# crypto\2024-12-08_22-02-11_SANDVNDC.png
# crypto\2024-12-08_22-02-25_SUIVNDC.png
# crypto\2024-12-08_22-02-44_1000CATVNDC.png
# crypto\2024-12-08_22-02-50_WLDVNDC.png
# crypto\2024-12-08_22-03-01_FOXYVNDC.png
# crypto\2024-12-08_22-04-05_UNIVNDC.png
# crypto\2024-12-08_22-05-17_MOODENGVNDC.png
# crypto\2024-12-08_22-15-09_LISTAVNDC.png
# crypto\2024-12-08_22-40-15_EGPT1000VNDC.png
# crypto\2024-12-08_22-44-07_MCAKEVNDC.png
# crypto\2024-12-08_23-33-04_OPVNDC.png
# crypto\2024-12-08_23-33-06_ENSVNDC.png
# crypto\2024-12-08_23-48-16_UNIVNDC.png
# crypto\2024-12-09_00-16-43_LINKVNDC.png
# crypto\2024-12-09_00-44-14_TRUVNDC.png
# crypto\2024-12-09_01-17-09_PEPE1000VNDC.png
# crypto\2024-12-09_01-29-12_TRUVNDC.png
# crypto\2024-12-09_01-29-16_AVAXVNDC.png
# crypto\2024-12-09_01-30-02_OPVNDC.png
# crypto\2024-12-09_01-30-06_TIAVNDC.png
# crypto\2024-12-09_01-30-07_WLDVNDC.png
# crypto\2024-12-09_01-30-13_DOGEVNDC.png
# crypto\2024-12-09_01-30-41_SUIVNDC.png
# crypto\2024-12-09_01-30-56_EGPT1000VNDC.png
# crypto\2024-12-09_01-30-56_MIAVNDC.png
# crypto\2024-12-09_01-31-01_DOTVNDC.png
# crypto\2024-12-09_01-31-03_LISTAVNDC.png
# crypto\2024-12-09_01-31-13_MOODENGVNDC.png
# crypto\2024-12-09_01-31-13_EDU3VNDC.png
# crypto\2024-12-09_01-31-14_MEON1000VNDC.png
# crypto\2024-12-09_01-31-14_DOGSVNDC.png
# crypto\2024-12-09_01-32-40_JASMYVNDC.png
# crypto\2024-12-09_01-33-20_GRASSVNDC.png
# crypto\2024-12-09_01-33-35_1000CATVNDC.png
# crypto\2024-12-09_01-36-16_LINKVNDC.png
# crypto\2024-12-09_02-24-19_PEPE1000VNDC.png
# crypto\2024-12-09_04-05-21_GRASSVNDC.png
# crypto\2024-12-09_04-54-25_PEPE1000VNDC.png
# crypto\2024-12-09_05-14-28_HBARVNDC.png
# crypto\2024-12-09_06-36-08_FOXYVNDC.png
# crypto\2024-12-09_07-10-07_EDU3VNDC.png
# crypto\2024-12-09_07-10-11_1000CATVNDC.png
# crypto\2024-12-09_07-10-22_CETUSVNDC.png
# crypto\2024-12-09_07-10-49_TIAVNDC.png
# crypto\2024-12-09_07-10-57_MCAKEVNDC.png
# crypto\2024-12-09_07-11-05_SANDVNDC.png
# crypto\2024-12-09_07-11-17_UXLINKVNDC.png
# crypto\2024-12-09_07-11-19_MEON1000VNDC.png
# crypto\2024-12-09_07-11-20_SUIVNDC.png
# crypto\2024-12-09_07-11-24_NEIROVNDC.png
# crypto\2024-12-09_07-12-11_BIGTIMEVNDC.png
# crypto\2024-12-09_07-12-14_XRPVNDC.png
# crypto\2024-12-09_07-12-16_XLMVNDC.png
# crypto\2024-12-09_07-14-11_ENSVNDC.png
# crypto\2024-12-09_07-23-17_EGPT1000VNDC.png
# crypto\2024-12-09_07-25-20_HBARVNDC.png
# crypto\2024-12-09_07-26-08_WLDVNDC.png
# crypto\2024-12-09_07-26-25_LISTAVNDC.png
# crypto\2024-12-09_07-47-05_HBARVNDC.png
# crypto\2024-12-09_08-01-13_AVAXVNDC.png
# crypto\2024-12-09_08-02-21_HBARVNDC.png
# crypto\2024-12-09_08-27-07_FOXYVNDC.png
# crypto\2024-12-09_08-55-04_LISTAVNDC.png
# crypto\2024-12-09_08-55-06_WLDVNDC.png
# crypto\2024-12-09_08-55-07_LDOVNDC.png
# crypto\2024-12-09_08-55-14_DOGEVNDC.png
# crypto\2024-12-09_08-55-20_OPVNDC.png
# crypto\2024-12-09_08-55-21_1000CATVNDC.png
# crypto\2024-12-09_08-55-43_SXPVNDC.png
# crypto\2024-12-09_08-55-49_NEIROVNDC.png
# crypto\2024-12-09_08-55-51_ENSVNDC.png
# crypto\2024-12-09_08-55-52_SANDVNDC.png
# crypto\2024-12-09_08-56-18_TIAVNDC.png
# crypto\2024-12-09_08-56-27_MCAKEVNDC.png
# crypto\2024-12-09_08-56-32_FOXYVNDC.png
# crypto\2024-12-09_09-32-04_SXPVNDC.png
# crypto\2024-12-09_09-32-11_SANDVNDC.png
# crypto\2024-12-09_09-32-38_JASMYVNDC.png
# crypto\2024-12-09_09-32-40_CKBVNDC.png
# crypto\2024-12-09_09-32-46_KSMVNDC.png
# crypto\2024-12-09_09-32-49_LISTAVNDC.png
# crypto\2024-12-09_09-33-03_XRPVNDC.png
# crypto\2024-12-09_09-48-04_MEON1000VNDC.png
# crypto\2024-12-09_09-48-06_DOGSVNDC.png
# crypto\2024-12-09_10-29-22_KSMVNDC.png
# crypto\2024-12-09_10-30-07_SXPVNDC.png
# crypto\2024-12-09_10-30-10_MIAVNDC.png
# crypto\2024-12-09_10-30-13_BIGTIMEVNDC.png
# crypto\2024-12-09_10-30-16_NEIROVNDC.png
# crypto\2024-12-09_10-30-32_OPVNDC.png
# crypto\2024-12-09_10-31-11_WLDVNDC.png
# crypto\2024-12-09_10-31-28_LISTAVNDC.png
# crypto\2024-12-09_10-32-18_AVAXVNDC.png
# crypto\2024-12-09_10-33-03_MEON1000VNDC.png
# crypto\2024-12-09_11-28-09_DOTVNDC.png
# crypto\2024-12-09_11-28-43_XLMVNDC.png
# crypto\2024-12-09_11-29-02_KSMVNDC.png
# crypto\2024-12-09_11-29-09_WLDVNDC.png
# crypto\2024-12-09_11-29-10_ADAVNDC.png
# crypto\2024-12-09_11-29-11_HBARVNDC.png
# crypto\2024-12-09_11-29-18_CETUSVNDC.png
# crypto\2024-12-09_11-29-26_NEIROVNDC.png
# crypto\2024-12-09_11-29-28_GRASSVNDC.png
# crypto\2024-12-09_11-30-12_JASMYVNDC.png
# crypto\2024-12-09_11-31-07_FOXYVNDC.png
# crypto\2024-12-09_11-44-12_LINKVNDC.png
# crypto\2024-12-09_12-24-06_EDU3VNDC.png
# crypto\2024-12-09_12-24-14_PEPE1000VNDC.png
# crypto\2024-12-09_12-25-51_WIFVNDC.png
# crypto\2024-12-09_13-16-08_LISTAVNDC.png
# crypto\2024-12-09_13-16-09_TIAVNDC.png
# crypto\2024-12-09_13-17-08_SXPVNDC.png
# crypto\2024-12-09_13-17-13_TRUVNDC.png
# crypto\2024-12-09_13-17-16_NEIROVNDC.png
# crypto\2024-12-09_13-17-50_KSMVNDC.png
# crypto\2024-12-09_13-18-06_OPVNDC.png
# crypto\2024-12-09_13-18-11_PEPE1000VNDC.png
# crypto\2024-12-09_13-18-13_WLDVNDC.png
# crypto\2024-12-09_13-18-23_MOODENGVNDC.png
# crypto\2024-12-09_13-18-29_GRASSVNDC.png
# crypto\2024-12-09_13-18-47_SANDVNDC.png
# crypto\2024-12-09_13-29-19_SUIVNDC.png
# crypto\2024-12-09_13-30-10_DOGSVNDC.png
# crypto\2024-12-09_13-34-15_DOGEVNDC.png
# crypto\2024-12-09_14-18-08_SOLVNDC.png
# crypto\2024-12-09_14-18-14_1000CATVNDC.png
# crypto\2024-12-09_14-18-55_LYNXVNDC.png
# crypto\2024-12-09_14-23-26_XRPVNDC.png
# crypto\2024-12-09_15-11-16_TIAVNDC.png
# crypto\2024-12-09_15-12-03_EDU3VNDC.png
# crypto\2024-12-09_15-13-37_CETUSVNDC.png
# crypto\2024-12-09_15-13-42_SUIVNDC.png
# crypto\2024-12-09_15-13-44_TRUVNDC.png
# crypto\2024-12-09_15-15-07_UNIVNDC.png
# crypto\2024-12-09_15-15-14_1000CATVNDC.png
# crypto\2024-12-09_16-03-07_GRASSVNDC.png
# crypto\2024-12-09_16-04-31_XLMVNDC.png
# crypto\2024-12-09_16-30-16_MOODENGVNDC.png
# crypto\2024-12-09_16-31-07_MEON1000VNDC.png
# crypto\2024-12-09_16-31-41_EGPT1000VNDC.png
# crypto\2024-12-09_16-32-07_LDOVNDC.png
# crypto\2024-12-09_16-32-15_MCAKEVNDC.png
# crypto\2024-12-09_16-32-19_DOGSVNDC.png
# crypto\2024-12-09_16-33-33_HBARVNDC.png
# crypto\2024-12-09_16-33-44_SUIVNDC.png
# crypto\2024-12-09_16-34-03_BIGTIMEVNDC.png
# crypto\2024-12-09_16-34-14_DOTVNDC.png
# crypto\2024-12-09_16-34-18_ADAVNDC.png
# crypto\2024-12-09_16-34-28_MIAVNDC.png
# crypto\2024-12-09_16-34-53_PEPE1000VNDC.png
# crypto\2024-12-09_16-35-56_XLMVNDC.png
# crypto\2024-12-09_16-36-15_ENSVNDC.png
# crypto\2024-12-09_16-36-17_SANDVNDC.png
# crypto\2024-12-09_16-36-18_GRASSVNDC.png
# crypto\2024-12-09_16-36-20_LISTAVNDC.png
# crypto\2024-12-09_16-39-19_CKBVNDC.png
# crypto\2024-12-09_16-41-24_CETUSVNDC.png
# crypto\2024-12-09_17-27-02_TIAVNDC.png
# crypto\2024-12-09_17-27-17_XLMVNDC.png
# crypto\2024-12-09_17-27-27_DOGEVNDC.png
# crypto\2024-12-09_17-29-17_PEPE1000VNDC.png
# crypto\2024-12-09_17-29-28_MOODENGVNDC.png
# crypto\2024-12-09_17-30-11_EGPT1000VNDC.png
# crypto\2024-12-09_17-30-14_MEON1000VNDC.png
# crypto\2024-12-09_17-30-16_TRUVNDC.png
# crypto\2024-12-09_17-30-20_DOTVNDC.png
# crypto\2024-12-09_17-30-21_ENSVNDC.png
# crypto\2024-12-09_17-30-23_GRASSVNDC.png
# crypto\2024-12-09_17-30-26_LDOVNDC.png
# crypto\2024-12-09_17-30-36_DOGSVNDC.png
# crypto\2024-12-09_17-30-38_BIGTIMEVNDC.png
# crypto\2024-12-09_17-30-51_MCAKEVNDC.png
# crypto\2024-12-09_18-14-11_EDU3VNDC.png
# crypto\2024-12-09_18-14-19_ADAVNDC.png
# crypto\2024-12-09_18-14-47_BIGTIMEVNDC.png
# crypto\2024-12-09_18-15-01_SOLVNDC.png
# crypto\2024-12-09_18-15-02_SXPVNDC.png
# crypto\2024-12-09_18-15-07_LINKVNDC.png
# crypto\2024-12-09_18-15-11_ENSVNDC.png
# crypto\2024-12-09_18-15-12_SANDVNDC.png
# crypto\2024-12-09_18-15-13_LYNXVNDC.png
# crypto\2024-12-09_18-15-17_HBARVNDC.png
# crypto\2024-12-09_18-15-27_SUIVNDC.png
# crypto\2024-12-09_18-15-30_WIFVNDC.png
# crypto\2024-12-09_18-15-34_AVAXVNDC.png
# crypto\2024-12-09_18-15-45_UXLINKVNDC.png
# crypto\2024-12-09_18-15-48_FOXYVNDC.png
# crypto\2024-12-09_18-16-06_TRUVNDC.png
# crypto\2024-12-09_18-16-10_GRASSVNDC.png
# crypto\2024-12-09_18-16-12_LISTAVNDC.png
# crypto\2024-12-09_18-16-14_LDOVNDC.png
# crypto\2024-12-09_18-16-21_JASMYVNDC.png
# crypto\2024-12-09_18-16-56_CKBVNDC.png
# crypto\2024-12-09_18-18-28_WLDVNDC.png
# crypto\2024-12-09_18-54-16_ADAVNDC.png
# crypto\2024-12-09_19-43-31_MIAVNDC.png
# crypto\2024-12-09_19-44-08_TRUVNDC.png
# crypto\2024-12-09_19-44-20_UNIVNDC.png
# crypto\2024-12-09_20-40-12_NEIROVNDC.png
# crypto\2024-12-09_20-53-03_MCAKEVNDC.png
# crypto\2024-12-09_20-53-05_EGPT1000VNDC.png
# crypto\2024-12-09_20-53-08_MEON1000VNDC.png
# crypto\2024-12-09_20-53-09_DOGSVNDC.png
# crypto\2024-12-09_21-07-05_GRASSVNDC.png
# crypto\2024-12-09_21-09-30_LDOVNDC.png
# crypto\2024-12-09_21-09-37_CETUSVNDC.png
# crypto\2024-12-09_21-09-43_BIGTIMEVNDC.png
# crypto\2024-12-09_21-10-48_EGPT1000VNDC.png
# crypto\2024-12-09_21-10-56_LISTAVNDC.png
# crypto\2024-12-09_21-11-39_MCAKEVNDC.png
# crypto\2024-12-09_21-16-05_UNIVNDC.png
# crypto\2024-12-09_21-21-10_MEON1000VNDC.png
# crypto\2024-12-09_21-32-10_TRUVNDC.png
# crypto\2024-12-09_22-25-13_SUIVNDC.png
# crypto\2024-12-09_22-25-13_BIGTIMEVNDC.png
# crypto\2024-12-09_22-25-15_WIFVNDC.png
# crypto\2024-12-09_22-25-16_ENSVNDC.png
# crypto\2024-12-09_22-25-18_TIAVNDC.png
# crypto\2024-12-09_22-25-19_PEPE1000VNDC.png
# crypto\2024-12-09_22-25-19_WLDVNDC.png
# crypto\2024-12-09_22-25-19_HBARVNDC.png
# crypto\2024-12-09_22-25-28_EDU3VNDC.png
# crypto\2024-12-09_22-26-03_OPVNDC.png
# crypto\2024-12-09_22-26-04_XLMVNDC.png
# crypto\2024-12-09_22-26-05_KSMVNDC.png
# crypto\2024-12-09_22-26-05_DOTVNDC.png
# crypto\2024-12-09_22-26-05_SANDVNDC.png
# crypto\2024-12-09_22-26-07_LISTAVNDC.png
# crypto\2024-12-09_22-26-08_ADAVNDC.png
# crypto\2024-12-09_22-26-14_DOGEVNDC.png
# crypto\2024-12-09_22-26-15_SXPVNDC.png
# crypto\2024-12-09_22-26-17_MIAVNDC.png
# crypto\2024-12-09_22-26-22_GRASSVNDC.png
# crypto\2024-12-09_22-26-23_AVAXVNDC.png
# crypto\2024-12-09_22-26-25_LDOVNDC.png
# crypto\2024-12-09_22-26-32_CKBVNDC.png
# crypto\2024-12-09_22-27-57_XRPVNDC.png
# crypto\2024-12-09_22-28-08_SOLVNDC.png
# crypto\2024-12-09_22-28-16_LYNXVNDC.png
# crypto\2024-12-09_22-45-12_BIGTIMEVNDC.png
# crypto\2024-12-09_22-45-12_OPVNDC.png
# crypto\2024-12-09_22-45-13_XRPVNDC.png
# crypto\2024-12-09_22-45-14_KSMVNDC.png
# crypto\2024-12-09_22-45-15_ENSVNDC.png
# crypto\2024-12-09_22-45-16_AVAXVNDC.png
# crypto\2024-12-09_22-45-17_LISTAVNDC.png
# crypto\2024-12-09_22-45-18_ADAVNDC.png
# crypto\2024-12-09_22-45-28_SUIVNDC.png
# crypto\2024-12-09_22-46-10_1000CATVNDC.png
# crypto\2024-12-09_22-56-15_LYNXVNDC.png
# crypto\2024-12-09_22-57-49_NEIROVNDC.png
# crypto\2024-12-09_23-00-14_LINKVNDC.png
# crypto\2024-12-09_23-00-19_HBARVNDC.png
# crypto\2024-12-09_23-11-29_LYNXVNDC.png
# crypto\2024-12-09_23-26-04_UNIVNDC.png
# crypto\2024-12-09_23-33-12_TRUVNDC.png
# crypto\2024-12-10_00-05-18_NEIROVNDC.png
# crypto\2024-12-10_00-23-06_CKBVNDC.png
# crypto\2024-12-10_00-29-17_KSMVNDC.png
# crypto\2024-12-10_00-43-18_BIGTIMEVNDC.png
# crypto\2024-12-10_00-44-05_MIAVNDC.png
# crypto\2024-12-10_00-44-06_MEON1000VNDC.png
# crypto\2024-12-10_00-44-20_MCAKEVNDC.png
# crypto\2024-12-10_00-44-27_GRASSVNDC.png
# crypto\2024-12-10_00-45-18_SXPVNDC.png
# crypto\2024-12-10_01-07-06_MCAKEVNDC.png
# crypto\2024-12-10_01-44-11_OPVNDC.png
# crypto\2024-12-10_01-44-16_WLDVNDC.png
# crypto\2024-12-10_01-44-29_ENSVNDC.png
# crypto\2024-12-10_01-45-02_AVAXVNDC.png
# crypto\2024-12-10_01-45-15_1000CATVNDC.png
# crypto\2024-12-10_01-45-18_GRASSVNDC.png
# crypto\2024-12-10_01-47-07_NEIROVNDC.png
# crypto\2024-12-10_02-09-13_NEIROVNDC.png
# crypto\2024-12-10_02-10-19_PEPE1000VNDC.png
# crypto\2024-12-10_02-11-03_LINKVNDC.png
# crypto\2024-12-10_02-11-04_WIFVNDC.png
# crypto\2024-12-10_02-12-10_DOTVNDC.png
# crypto\2024-12-10_02-12-12_TIAVNDC.png
# crypto\2024-12-10_02-12-12_WLDVNDC.png
# crypto\2024-12-10_02-12-19_CETUSVNDC.png
# crypto\2024-12-10_02-13-07_DOGEVNDC.png
# crypto\2024-12-10_02-13-07_JASMYVNDC.png
# crypto\2024-12-10_02-13-09_MIAVNDC.png
# crypto\2024-12-10_02-13-09_EDU3VNDC.png
# crypto\2024-12-10_02-13-11_OPVNDC.png
# crypto\2024-12-10_02-13-13_XLMVNDC.png
# crypto\2024-12-10_02-13-16_ADAVNDC.png
# crypto\2024-12-10_02-14-12_SXPVNDC.png
# crypto\2024-12-10_02-14-14_DOGSVNDC.png
# crypto\2024-12-10_02-14-14_FOXYVNDC.png
# crypto\2024-12-10_02-14-17_KSMVNDC.png
# crypto\2024-12-10_02-15-08_LDOVNDC.png
# crypto\2024-12-10_02-15-21_SANDVNDC.png
# crypto\2024-12-10_02-15-53_ENSVNDC.png
# crypto\2024-12-10_02-17-13_GRASSVNDC.png
# crypto\2024-12-10_02-54-12_JASMYVNDC.png
# crypto\2024-12-10_03-01-14_MOODENGVNDC.png
# crypto\2024-12-10_03-01-17_NEIROVNDC.png
# crypto\2024-12-10_03-05-49_GRASSVNDC.png
# crypto\2024-12-10_03-06-52_TIAVNDC.png
# crypto\2024-12-10_03-17-24_ADAVNDC.png
# crypto\2024-12-10_03-18-05_TRUVNDC.png
# crypto\2024-12-10_03-18-06_1000CATVNDC.png
# crypto\2024-12-10_03-18-18_CKBVNDC.png
# crypto\2024-12-10_03-18-24_SANDVNDC.png
# crypto\2024-12-10_03-19-06_MOODENGVNDC.png
# crypto\2024-12-10_03-33-06_MEON1000VNDC.png
# crypto\2024-12-10_03-33-07_DOGSVNDC.png
# crypto\2024-12-10_03-33-11_AVAXVNDC.png
# crypto\2024-12-10_03-33-49_UNIVNDC.png
# crypto\2024-12-10_03-35-03_MOODENGVNDC.png
# crypto\2024-12-10_03-35-05_TRUVNDC.png
# crypto\2024-12-10_03-35-08_SANDVNDC.png
# crypto\2024-12-10_03-35-19_MIAVNDC.png
# crypto\2024-12-10_03-35-20_EDU3VNDC.png
# crypto\2024-12-10_03-35-33_DOGEVNDC.png
# crypto\2024-12-10_03-35-42_WLDVNDC.png
# crypto\2024-12-10_03-46-16_LISTAVNDC.png
# crypto\2024-12-10_03-57-17_XLMVNDC.png
# crypto\2024-12-10_03-57-28_UXLINKVNDC.png
# crypto\2024-12-10_03-57-49_KSMVNDC.png
# crypto\2024-12-10_03-57-51_TIAVNDC.png
# crypto\2024-12-10_03-58-23_CETUSVNDC.png
# crypto\2024-12-10_03-58-24_CKBVNDC.png
# crypto\2024-12-10_03-58-27_BIGTIMEVNDC.png
# crypto\2024-12-10_03-58-32_WLDVNDC.png
# crypto\2024-12-10_03-58-57_MOODENGVNDC.png
# crypto\2024-12-10_04-11-27_1000CATVNDC.png
# crypto\2024-12-10_04-53-41_DOGEVNDC.png
# crypto\2024-12-10_04-53-48_LYNXVNDC.png
# crypto\2024-12-10_04-55-01_MIAVNDC.png
# crypto\2024-12-10_04-55-03_BIGTIMEVNDC.png
# crypto\2024-12-10_04-55-04_OPVNDC.png
# crypto\2024-12-10_04-55-05_WIFVNDC.png
# crypto\2024-12-10_04-55-06_KSMVNDC.png
# crypto\2024-12-10_04-55-06_DOTVNDC.png
# crypto\2024-12-10_04-55-07_SANDVNDC.png
# crypto\2024-12-10_04-55-15_CETUSVNDC.png
# crypto\2024-12-10_04-55-16_JASMYVNDC.png
# crypto\2024-12-10_04-55-16_SXPVNDC.png
# crypto\2024-12-10_04-55-18_EDU3VNDC.png
# crypto\2024-12-10_04-55-19_SUIVNDC.png
# crypto\2024-12-10_04-55-20_LINKVNDC.png
# crypto\2024-12-10_04-55-21_1000CATVNDC.png
# crypto\2024-12-10_04-55-24_WLDVNDC.png
# crypto\2024-12-10_04-55-25_HBARVNDC.png
# crypto\2024-12-10_04-56-17_XLMVNDC.png
# crypto\2024-12-10_04-56-49_ENSVNDC.png
# crypto\2024-12-10_04-57-49_CKBVNDC.png
# crypto\2024-12-10_04-57-56_TIAVNDC.png
# crypto\2024-12-10_04-57-57_LDOVNDC.png
# crypto\2024-12-10_04-58-51_UXLINKVNDC.png
# crypto\2024-12-10_05-12-31_LINKVNDC.png
# crypto\2024-12-10_07-00-46_NEIROVNDC.png
# crypto\2024-12-10_07-10-17_WIFVNDC.png
# crypto\2024-12-10_07-10-22_DOTVNDC.png
# crypto\2024-12-10_07-13-21_UNIVNDC.png
# crypto\2024-12-10_07-14-22_LDOVNDC.png
# crypto\2024-12-10_07-15-39_MOODENGVNDC.png
# crypto\2024-12-10_07-15-46_BIGTIMEVNDC.png
# crypto\2024-12-10_07-16-02_CKBVNDC.png
# crypto\2024-12-10_07-17-06_SXPVNDC.png
# crypto\2024-12-10_07-36-19_UXLINKVNDC.png
# crypto\2024-12-10_07-50-06_WIFVNDC.png
# crypto\2024-12-10_08-02-07_MCAKEVNDC.png
# crypto\2024-12-10_08-02-11_EGPT1000VNDC.png
# crypto\2024-12-10_08-03-04_CETUSVNDC.png
# crypto\2024-12-10_08-19-50_ENSVNDC.png
# crypto\2024-12-10_08-19-54_GRASSVNDC.png
# crypto\2024-12-10_08-20-05_SXPVNDC.png
# crypto\2024-12-10_08-20-41_MIAVNDC.png
# crypto\2024-12-10_08-20-44_MEON1000VNDC.png
# crypto\2024-12-10_08-21-10_WLDVNDC.png
# crypto\2024-12-10_08-21-21_EGPT1000VNDC.png
# crypto\2024-12-10_08-21-29_TRUVNDC.png
# crypto\2024-12-10_08-21-48_DOTVNDC.png
# crypto\2024-12-10_08-24-25_UXLINKVNDC.png
# crypto\2024-12-10_08-30-11_PEPE1000VNDC.png
# crypto\2024-12-10_08-40-09_BIGTIMEVNDC.png
# crypto\2024-12-10_08-42-14_CKBVNDC.png
# crypto\2024-12-10_08-42-17_MEON1000VNDC.png
# crypto\2024-12-10_08-43-06_EGPT1000VNDC.png
# crypto\2024-12-10_08-43-13_LISTAVNDC.png
# crypto\2024-12-10_08-43-22_SOLVNDC.png
# crypto\2024-12-10_08-43-32_WLDVNDC.png
# crypto\2024-12-10_08-43-48_LYNXVNDC.png
# crypto\2024-12-10_09-13-17_LYNXVNDC.png
# crypto\2024-12-10_09-13-28_UXLINKVNDC.png
# crypto\2024-12-10_09-14-03_MIAVNDC.png
# crypto\2024-12-10_09-14-09_GRASSVNDC.png
# crypto\2024-12-10_09-14-12_ADAVNDC.png
# crypto\2024-12-10_09-14-18_UNIVNDC.png
# crypto\2024-12-10_09-14-20_SOLVNDC.png
# crypto\2024-12-10_09-14-25_BIGTIMEVNDC.png
# crypto\2024-12-10_09-14-27_WIFVNDC.png
# crypto\2024-12-10_09-15-05_PEPE1000VNDC.png
# crypto\2024-12-10_09-15-13_SXPVNDC.png
# crypto\2024-12-10_09-15-16_EDU3VNDC.png
# crypto\2024-12-10_09-15-20_1000CATVNDC.png
# crypto\2024-12-10_09-15-34_MOODENGVNDC.png
# crypto\2024-12-10_09-15-54_XRPVNDC.png
# crypto\2024-12-10_09-16-08_MCAKEVNDC.png
# crypto\2024-12-10_09-16-09_EGPT1000VNDC.png
# crypto\2024-12-10_09-16-29_MEON1000VNDC.png
# crypto\2024-12-10_09-16-34_SANDVNDC.png
# crypto\2024-12-10_09-16-47_DOGSVNDC.png
# crypto\2024-12-10_09-19-11_CKBVNDC.png
# crypto\2024-12-10_09-32-14_EGPT1000VNDC.png
# crypto\2024-12-10_09-32-17_FOXYVNDC.png
# crypto\2024-12-10_09-36-14_UNIVNDC.png
# crypto\2024-12-10_09-37-10_XLMVNDC.png
# crypto\2024-12-10_10-02-08_FOXYVNDC.png
# crypto\2024-12-10_10-02-24_MOODENGVNDC.png
# crypto\2024-12-10_10-03-03_SANDVNDC.png
# crypto\2024-12-10_10-03-05_WLDVNDC.png
# crypto\2024-12-10_10-03-13_CETUSVNDC.png
# crypto\2024-12-10_10-03-15_JASMYVNDC.png
# crypto\2024-12-10_10-03-21_XRPVNDC.png
# crypto\2024-12-10_10-03-23_NEIROVNDC.png
# crypto\2024-12-10_10-03-25_ENSVNDC.png
# crypto\2024-12-10_10-04-08_MCAKEVNDC.png
# crypto\2024-12-10_10-04-10_EGPT1000VNDC.png
# crypto\2024-12-10_10-04-11_UXLINKVNDC.png
# crypto\2024-12-10_10-04-12_MIAVNDC.png
# crypto\2024-12-10_10-04-14_MEON1000VNDC.png
# crypto\2024-12-10_10-04-16_DOGSVNDC.png
# crypto\2024-12-10_10-04-18_OPVNDC.png
# crypto\2024-12-10_10-04-20_1000CATVNDC.png
# crypto\2024-12-10_10-04-22_XLMVNDC.png
# crypto\2024-12-10_10-04-23_KSMVNDC.png
# crypto\2024-12-10_10-04-24_DOTVNDC.png
# crypto\2024-12-10_10-04-26_AVAXVNDC.png
# crypto\2024-12-10_10-04-28_TIAVNDC.png
# crypto\2024-12-10_10-04-30_LDOVNDC.png
# crypto\2024-12-10_10-05-35_SUIVNDC.png
# crypto\2024-12-10_10-05-50_ADAVNDC.png
# crypto\2024-12-10_10-06-02_TRUVNDC.png
# crypto\2024-12-10_10-07-04_LISTAVNDC.png
# crypto\2024-12-10_10-07-39_PEPE1000VNDC.png
# crypto\2024-12-10_10-18-08_UNIVNDC.png
# crypto\2024-12-10_10-18-11_CKBVNDC.png
# crypto\2024-12-10_10-18-26_CETUSVNDC.png
# crypto\2024-12-10_10-18-28_SOLVNDC.png
# crypto\2024-12-10_10-18-29_SXPVNDC.png
# crypto\2024-12-10_10-18-35_XRPVNDC.png
# crypto\2024-12-10_10-18-38_SANDVNDC.png
# crypto\2024-12-10_10-18-47_DOGEVNDC.png
# crypto\2024-12-10_10-18-58_WLDVNDC.png
# crypto\2024-12-10_10-20-16_XLMVNDC.png
# crypto\2024-12-10_10-20-17_DOTVNDC.png
# crypto\2024-12-10_10-20-20_AVAXVNDC.png
# crypto\2024-12-10_10-20-50_NEIROVNDC.png
# crypto\2024-12-10_10-21-23_WIFVNDC.png
# crypto\2024-12-10_10-21-27_TIAVNDC.png
# crypto\2024-12-10_10-21-37_MIAVNDC.png
# crypto\2024-12-10_10-21-39_EDU3VNDC.png
# crypto\2024-12-10_10-21-40_DOGSVNDC.png
# crypto\2024-12-10_10-31-18_JASMYVNDC.png
# crypto\2024-12-10_12-29-03_NEIROVNDC.png
# crypto\2024-12-10_12-29-05_SANDVNDC.png
# crypto\2024-12-10_12-29-07_LISTAVNDC.png
# crypto\2024-12-10_12-29-09_PEPE1000VNDC.png
# crypto\2024-12-10_12-29-19_MOODENGVNDC.png
# crypto\2024-12-10_12-30-28_TRUVNDC.png
# crypto\2024-12-10_12-31-15_UXLINKVNDC.png
# crypto\2024-12-10_13-23-09_FOXYVNDC.png
# crypto\2024-12-10_13-54-17_LYNXVNDC.png
# crypto\2024-12-10_13-55-16_EGPT1000VNDC.png
# crypto\2024-12-10_14-09-38_FOXYVNDC.png
# crypto\2024-12-10_14-10-10_MOODENGVNDC.png
# crypto\2024-12-10_14-10-11_MEON1000VNDC.png
# crypto\2024-12-10_14-10-27_EGPT1000VNDC.png
# crypto\2024-12-10_14-10-32_XLMVNDC.png
# crypto\2024-12-10_14-10-49_1000CATVNDC.png
# crypto\2024-12-10_14-45-16_ENSVNDC.png
# crypto\2024-12-10_15-00-04_NEIROVNDC.png
# crypto\2024-12-10_15-09-39_GRASSVNDC.png
# crypto\2024-12-10_15-16-11_FOXYVNDC.png
# crypto\2024-12-10_15-17-26_LINKVNDC.png
# crypto\2024-12-10_15-20-04_MIAVNDC.png
# crypto\2024-12-10_15-20-22_DOGSVNDC.png
# crypto\2024-12-10_15-20-39_MEON1000VNDC.png
# crypto\2024-12-10_15-45-16_NEIROVNDC.png
# crypto\2024-12-10_16-34-13_1000CATVNDC.png
# crypto\2024-12-10_16-35-04_WIFVNDC.png
# crypto\2024-12-10_16-35-08_WLDVNDC.png
# crypto\2024-12-10_16-36-05_CETUSVNDC.png
# crypto\2024-12-10_16-36-13_NEIROVNDC.png
# crypto\2024-12-10_16-36-26_CKBVNDC.png
# crypto\2024-12-10_16-37-05_XLMVNDC.png
# crypto\2024-12-10_16-38-09_FOXYVNDC.png
# crypto\2024-12-10_16-38-14_GRASSVNDC.png
# crypto\2024-12-10_16-50-08_EGPT1000VNDC.png
# crypto\2024-12-10_16-50-13_WIFVNDC.png
# crypto\2024-12-10_16-50-31_XRPVNDC.png
# crypto\2024-12-10_16-51-08_AVAXVNDC.png
# crypto\2024-12-10_16-51-19_MOODENGVNDC.png
# crypto\2024-12-10_16-51-35_CKBVNDC.png
# crypto\2024-12-10_16-52-08_JASMYVNDC.png
# crypto\2024-12-10_16-52-09_SXPVNDC.png
# crypto\2024-12-10_16-52-11_UXLINKVNDC.png
# crypto\2024-12-10_16-52-15_LINKVNDC.png
# crypto\2024-12-10_16-52-17_KSMVNDC.png
# crypto\2024-12-10_16-55-43_LDOVNDC.png
# crypto\2024-12-10_17-31-06_LDOVNDC.png
# crypto\2024-12-10_17-31-14_MCAKEVNDC.png
# crypto\2024-12-10_17-31-19_LINKVNDC.png
# crypto\2024-12-10_18-46-27_UXLINKVNDC.png
# crypto\2024-12-10_18-47-16_HBARVNDC.png
# crypto\2024-12-10_18-49-38_JASMYVNDC.png
# crypto\2024-12-10_18-49-49_LDOVNDC.png
# crypto\2024-12-10_19-20-27_WLDVNDC.png
# crypto\2024-12-10_19-20-41_NEIROVNDC.png
# crypto\2024-12-10_19-20-54_UXLINKVNDC.png
# crypto\2024-12-10_19-21-10_CKBVNDC.png
# crypto\2024-12-10_19-23-14_DOTVNDC.png
# crypto\2024-12-10_19-23-57_UNIVNDC.png
# crypto\2024-12-10_19-51-34_FOXYVNDC.png
# crypto\2024-12-10_20-00-03_AVAXVNDC.png
# crypto\2024-12-10_20-00-16_BIGTIMEVNDC.png
# crypto\2024-12-10_20-00-21_GRASSVNDC.png
# crypto\2024-12-10_21-02-05_NEIROVNDC.png
# crypto\2024-12-10_21-02-23_XLMVNDC.png
# crypto\2024-12-10_21-25-11_UNIVNDC.png
# crypto\2024-12-10_21-43-11_UNIVNDC.png
# crypto\2024-12-10_21-46-05_DOGSVNDC.png
# crypto\2024-12-10_21-46-12_GRASSVNDC.png
# crypto\2024-12-10_21-47-13_MCAKEVNDC.png
# crypto\2024-12-10_22-03-02_LINKVNDC.png
# crypto\2024-12-10_22-03-15_MOODENGVNDC.png
# crypto\2024-12-10_22-03-15_EDU3VNDC.png
# crypto\2024-12-10_22-03-16_DOGSVNDC.png
# crypto\2024-12-10_22-05-01_WLDVNDC.png
# crypto\2024-12-10_22-29-08_EDU3VNDC.png
# crypto\2024-12-10_22-29-11_NEIROVNDC.png
# crypto\2024-12-10_22-30-09_MOODENGVNDC.png
# crypto\2024-12-10_22-30-11_FOXYVNDC.png
# crypto\2024-12-10_22-33-37_EGPT1000VNDC.png
# crypto\2024-12-10_22-33-39_DOGSVNDC.png
# crypto\2024-12-10_22-34-07_UNIVNDC.png
# crypto\2024-12-10_22-34-13_LINKVNDC.png
# crypto\2024-12-10_22-35-17_GRASSVNDC.png
# crypto\2024-12-10_22-35-49_LDOVNDC.png
# crypto\2024-12-10_22-36-05_HBARVNDC.png
# crypto\2024-12-10_22-37-13_AVAXVNDC.png
# crypto\2024-12-10_22-38-00_ADAVNDC.png
# crypto\2024-12-10_22-39-42_TRUVNDC.png
# crypto\2024-12-10_22-47-07_XRPVNDC.png
# crypto\2024-12-10_22-49-13_DOGEVNDC.png
# crypto\2024-12-10_22-49-18_LINKVNDC.png
# crypto\2024-12-10_22-49-22_WLDVNDC.png
# crypto\2024-12-10_22-50-06_DOTVNDC.png
# crypto\2024-12-10_22-50-18_DOGSVNDC.png
# crypto\2024-12-10_22-51-07_KSMVNDC.png
# crypto\2024-12-10_22-52-26_AVAXVNDC.png
# crypto\2024-12-10_23-03-10_CKBVNDC.png
# crypto\2024-12-10_23-05-12_SXPVNDC.png
# crypto\2024-12-10_23-05-18_DOTVNDC.png
# crypto\2024-12-10_23-06-29_LDOVNDC.png
# crypto\2024-12-10_23-07-47_HBARVNDC.png
# crypto\2024-12-10_23-08-12_TRUVNDC.png
# crypto\2024-12-10_23-08-30_SANDVNDC.png
# crypto\2024-12-10_23-13-05_LISTAVNDC.png
# crypto\2024-12-10_23-13-12_CETUSVNDC.png
# crypto\2024-12-10_23-18-10_KSMVNDC.png
# crypto\2024-12-10_23-40-08_NEIROVNDC.png
# crypto\2024-12-10_23-47-12_UNIVNDC.png
# crypto\2024-12-11_00-12-07_LISTAVNDC.png
# crypto\2024-12-11_00-14-49_SUIVNDC.png
# crypto\2024-12-11_00-28-18_1000CATVNDC.png
# crypto\2024-12-11_00-29-05_KSMVNDC.png
# crypto\2024-12-11_00-34-06_SOLVNDC.png
# crypto\2024-12-11_00-35-09_DOGSVNDC.png
# crypto\2024-12-11_00-35-24_MOODENGVNDC.png
# crypto\2024-12-11_00-36-08_LYNXVNDC.png
# crypto\2024-12-11_00-36-59_DOGEVNDC.png
# crypto\2024-12-11_00-37-02_EDU3VNDC.png
# crypto\2024-12-11_00-44-08_CKBVNDC.png
# crypto\2024-12-11_00-44-13_XLMVNDC.png
# crypto\2024-12-11_00-44-27_1000CATVNDC.png
# crypto\2024-12-11_00-54-49_UNIVNDC.png
# crypto\2024-12-11_01-04-16_LYNXVNDC.png
# crypto\2024-12-11_01-05-10_SOLVNDC.png
# crypto\2024-12-11_01-05-12_DOGSVNDC.png
# crypto\2024-12-11_01-05-14_XRPVNDC.png
# crypto\2024-12-11_01-05-29_LINKVNDC.png
# crypto\2024-12-11_01-05-33_HBARVNDC.png
# crypto\2024-12-11_01-06-10_JASMYVNDC.png
# crypto\2024-12-11_01-06-18_GRASSVNDC.png
# crypto\2024-12-11_01-06-27_UXLINKVNDC.png
# crypto\2024-12-11_01-08-40_ADAVNDC.png
# crypto\2024-12-11_01-08-51_MOODENGVNDC.png
# crypto\2024-12-11_01-08-51_EDU3VNDC.png
# crypto\2024-12-11_01-08-53_OPVNDC.png
# crypto\2024-12-11_01-08-55_XLMVNDC.png
# crypto\2024-12-11_01-08-59_LDOVNDC.png
# crypto\2024-12-11_01-09-39_1000CATVNDC.png
# crypto\2024-12-11_01-09-41_ENSVNDC.png
# crypto\2024-12-11_02-02-10_SOLVNDC.png
# crypto\2024-12-11_02-02-15_1000CATVNDC.png
# crypto\2024-12-11_02-02-17_LYNXVNDC.png
# crypto\2024-12-11_02-03-11_MCAKEVNDC.png
# crypto\2024-12-11_02-37-10_WIFVNDC.png
# crypto\2024-12-11_02-37-10_NEIROVNDC.png
# crypto\2024-12-11_02-38-13_GRASSVNDC.png
# crypto\2024-12-11_02-57-09_JASMYVNDC.png
# crypto\2024-12-11_04-25-59_ADAVNDC.png
# crypto\2024-12-11_04-54-12_WIFVNDC.png
# crypto\2024-12-11_04-54-22_DOGEVNDC.png
# crypto\2024-12-11_05-24-27_CETUSVNDC.png
# crypto\2024-12-11_05-51-05_LYNXVNDC.png
# crypto\2024-12-11_05-51-06_PEPE1000VNDC.png
# crypto\2024-12-11_05-51-13_UNIVNDC.png
# crypto\2024-12-11_05-52-04_OPVNDC.png
# crypto\2024-12-11_06-32-29_JASMYVNDC.png
# crypto\2024-12-11_06-34-11_GRASSVNDC.png
# crypto\2024-12-11_06-38-20_HBARVNDC.png
# crypto\2024-12-11_06-50-04_EDU3VNDC.png
# crypto\2024-12-11_06-56-31_1000CATVNDC.png
# crypto\2024-12-11_07-21-13_LYNXVNDC.png
# crypto\2024-12-11_07-23-06_PEPE1000VNDC.png
# crypto\2024-12-11_07-23-08_ADAVNDC.png
# crypto\2024-12-11_07-23-09_HBARVNDC.png
# crypto\2024-12-11_07-23-19_SUIVNDC.png
# crypto\2024-12-11_07-23-22_XRPVNDC.png
# crypto\2024-12-11_07-23-23_WIFVNDC.png
# crypto\2024-12-11_07-23-37_MOODENGVNDC.png
# crypto\2024-12-11_07-23-39_FOXYVNDC.png
# crypto\2024-12-11_07-23-41_LINKVNDC.png
# crypto\2024-12-11_07-23-53_DOGEVNDC.png
# crypto\2024-12-11_07-24-16_NEIROVNDC.png
# crypto\2024-12-11_07-24-19_AVAXVNDC.png
# crypto\2024-12-11_07-24-34_ENSVNDC.png
# crypto\2024-12-11_07-31-12_XLMVNDC.png
# crypto\2024-12-11_07-48-11_DOTVNDC.png
# crypto\2024-12-11_07-48-29_SANDVNDC.png
# crypto\2024-12-11_07-50-05_XLMVNDC.png
# crypto\2024-12-11_07-50-26_LDOVNDC.png
# crypto\2024-12-11_08-10-09_AVAXVNDC.png
# crypto\2024-12-11_08-32-14_PEPE1000VNDC.png
# crypto\2024-12-11_08-32-16_ADAVNDC.png
# crypto\2024-12-11_08-33-04_AVAXVNDC.png
# crypto\2024-12-11_08-33-05_LISTAVNDC.png
# crypto\2024-12-11_08-33-08_HBARVNDC.png
# crypto\2024-12-11_08-33-09_LDOVNDC.png
# crypto\2024-12-11_08-33-15_DOGEVNDC.png
# crypto\2024-12-11_08-33-17_SOLVNDC.png
# crypto\2024-12-11_08-33-18_SXPVNDC.png
# crypto\2024-12-11_08-33-21_MEON1000VNDC.png
# crypto\2024-12-11_08-33-25_1000CATVNDC.png
# crypto\2024-12-11_08-33-26_WIFVNDC.png
# crypto\2024-12-11_08-33-27_NEIROVNDC.png
# crypto\2024-12-11_08-33-29_KSMVNDC.png
# crypto\2024-12-11_08-33-31_SANDVNDC.png
# crypto\2024-12-11_08-33-45_XRPVNDC.png
# crypto\2024-12-11_08-34-05_MCAKEVNDC.png
# crypto\2024-12-11_08-34-10_BIGTIMEVNDC.png
# crypto\2024-12-11_08-34-13_XLMVNDC.png
# crypto\2024-12-11_08-34-26_EDU3VNDC.png
# crypto\2024-12-11_08-34-34_WLDVNDC.png
# crypto\2024-12-11_08-34-44_MOODENGVNDC.png
# crypto\2024-12-11_08-37-07_UXLINKVNDC.png
# crypto\2024-12-11_09-04-09_SOLVNDC.png
# crypto\2024-12-11_09-04-16_WIFVNDC.png
# crypto\2024-12-11_09-04-19_LYNXVNDC.png
# crypto\2024-12-11_09-04-21_AVAXVNDC.png
# crypto\2024-12-11_09-04-35_1000CATVNDC.png
# crypto\2024-12-11_09-05-03_JASMYVNDC.png
# crypto\2024-12-11_09-05-06_MIAVNDC.png
# crypto\2024-12-11_09-05-09_BIGTIMEVNDC.png
# crypto\2024-12-11_09-05-13_DOTVNDC.png
# crypto\2024-12-11_09-05-16_TIAVNDC.png
# crypto\2024-12-11_09-05-18_HBARVNDC.png
# crypto\2024-12-11_09-05-28_DOGSVNDC.png
# crypto\2024-12-11_09-05-47_LINKVNDC.png
# crypto\2024-12-11_09-05-52_WLDVNDC.png
# crypto\2024-12-11_09-06-20_OPVNDC.png
# crypto\2024-12-11_09-06-23_XLMVNDC.png
# crypto\2024-12-11_10-30-06_MCAKEVNDC.png
# crypto\2024-12-11_10-30-08_EGPT1000VNDC.png
# crypto\2024-12-11_10-30-10_MEON1000VNDC.png
# crypto\2024-12-11_10-30-11_DOGSVNDC.png
# crypto\2024-12-11_11-16-03_BIGTIMEVNDC.png
# crypto\2024-12-11_11-16-08_LYNXVNDC.png
# crypto\2024-12-11_11-17-11_TRUVNDC.png
# crypto\2024-12-11_12-16-08_CKBVNDC.png
# crypto\2024-12-11_12-16-16_LYNXVNDC.png
# crypto\2024-12-11_12-18-12_JASMYVNDC.png
# crypto\2024-12-11_12-18-17_BIGTIMEVNDC.png
# crypto\2024-12-11_12-18-18_TRUVNDC.png
# crypto\2024-12-11_12-18-21_XLMVNDC.png
# crypto\2024-12-11_12-18-42_HBARVNDC.png
# crypto\2024-12-11_12-19-23_SXPVNDC.png
# crypto\2024-12-11_12-19-32_PEPE1000VNDC.png
# crypto\2024-12-11_12-20-35_NEIROVNDC.png
# crypto\2024-12-11_12-41-08_LISTAVNDC.png
# crypto\2024-12-11_14-18-12_UNIVNDC.png
# crypto\2024-12-11_14-18-50_MOODENGVNDC.png
# crypto\2024-12-11_14-18-54_1000CATVNDC.png
# crypto\2024-12-11_14-23-13_NEIROVNDC.png
# crypto\2024-12-11_14-23-14_XLMVNDC.png
# crypto\2024-12-11_14-23-31_XRPVNDC.png
# crypto\2024-12-11_14-30-26_LDOVNDC.png
# crypto\2024-12-11_14-56-14_LDOVNDC.png
# crypto\2024-12-11_14-57-13_UXLINKVNDC.png
# crypto\2024-12-11_14-57-17_LINKVNDC.png
# crypto\2024-12-11_14-57-50_SUIVNDC.png
# crypto\2024-12-11_14-58-19_UNIVNDC.png
# crypto\2024-12-11_14-58-22_EGPT1000VNDC.png
# crypto\2024-12-11_14-58-30_TIAVNDC.png
# crypto\2024-12-11_14-58-41_MIAVNDC.png
# crypto\2024-12-11_14-58-43_DOGSVNDC.png
# crypto\2024-12-11_14-59-03_KSMVNDC.png
# crypto\2024-12-11_15-20-04_LYNXVNDC.png
# crypto\2024-12-11_15-58-07_GRASSVNDC.png
# crypto\2024-12-11_15-59-16_JASMYVNDC.png
# crypto\2024-12-11_15-59-22_1000CATVNDC.png
# crypto\2024-12-11_16-21-31_GRASSVNDC.png
# crypto\2024-12-11_16-33-55_XRPVNDC.png
# crypto\2024-12-11_16-34-26_HBARVNDC.png
# crypto\2024-12-11_17-21-10_MOODENGVNDC.png
# crypto\2024-12-11_17-21-15_KSMVNDC.png
# crypto\2024-12-11_18-52-09_LINKVNDC.png
# crypto\2024-12-11_18-55-52_XLMVNDC.png
# crypto\2024-12-11_18-55-54_SANDVNDC.png
# crypto\2024-12-11_19-18-27_GRASSVNDC.png
# crypto\2024-12-11_19-57-17_MCAKEVNDC.png
# crypto\2024-12-11_19-57-20_EGPT1000VNDC.png
# crypto\2024-12-11_19-57-23_MEON1000VNDC.png
# crypto\2024-12-11_19-58-14_JASMYVNDC.png
# crypto\2024-12-11_20-00-20_1000CATVNDC.png
# crypto\2024-12-11_20-23-03_XLMVNDC.png
# crypto\2024-12-11_20-23-14_JASMYVNDC.png
# crypto\2024-12-11_20-25-15_SANDVNDC.png
# crypto\2024-12-11_20-57-59_ENSVNDC.png
# crypto\2024-12-11_21-16-10_XLMVNDC.png
# crypto\2024-12-11_21-20-22_WIFVNDC.png
# crypto\2024-12-11_22-49-22_GRASSVNDC.png
# crypto\2024-12-11_23-02-05_LYNXVNDC.png
# crypto\2024-12-11_23-18-37_1000CATVNDC.png
# crypto\2024-12-11_23-24-08_LYNXVNDC.png
# crypto\2024-12-11_23-25-58_HBARVNDC.png
# crypto\2024-12-11_23-41-55_LDOVNDC.png
# crypto\2024-12-11_23-45-13_DOGEVNDC.png
# crypto\2024-12-11_23-49-10_LINKVNDC.png
# crypto\2024-12-11_23-49-27_KSMVNDC.png
# crypto\2024-12-11_23-49-40_TRUVNDC.png
# crypto\2024-12-12_00-04-30_MOODENGVNDC.png
# crypto\2024-12-12_00-35-25_CETUSVNDC.png
# crypto\2024-12-12_01-05-22_JASMYVNDC.png
# crypto\2024-12-12_01-39-44_LYNXVNDC.png
# crypto\2024-12-12_01-50-32_FOXYVNDC.png
# crypto\2024-12-12_02-01-19_JASMYVNDC.png
# crypto\2024-12-12_02-21-24_UNIVNDC.png
# crypto\2024-12-12_02-21-44_XRPVNDC.png
# crypto\2024-12-12_03-19-16_DOGSVNDC.png
# crypto\2024-12-12_03-41-08_NEIROVNDC.png
# crypto\2024-12-12_03-45-15_JASMYVNDC.png
# crypto\2024-12-12_03-45-16_UXLINKVNDC.png
# crypto\2024-12-12_03-57-14_MOODENGVNDC.png
# crypto\2024-12-12_03-58-13_PEPE1000VNDC.png
# crypto\2024-12-12_03-58-22_DOGSVNDC.png
# crypto\2024-12-12_03-58-35_EGPT1000VNDC.png
# crypto\2024-12-12_03-58-37_MEON1000VNDC.png
# crypto\2024-12-12_03-59-10_EDU3VNDC.png
# crypto\2024-12-12_03-59-15_WLDVNDC.png
# crypto\2024-12-12_03-59-26_LINKVNDC.png
# crypto\2024-12-12_04-00-11_1000CATVNDC.png
# crypto\2024-12-12_04-00-22_UXLINKVNDC.png
# crypto\2024-12-12_04-00-34_NEIROVNDC.png
# crypto\2024-12-12_04-01-13_JASMYVNDC.png
# crypto\2024-12-12_04-12-07_SUIVNDC.png
# crypto\2024-12-12_04-14-06_BIGTIMEVNDC.png
# crypto\2024-12-12_04-15-09_GRASSVNDC.png
# crypto\2024-12-12_04-59-23_CETUSVNDC.png
# crypto\2024-12-12_05-21-16_GRASSVNDC.png
# crypto\2024-12-12_05-25-04_ENSVNDC.png
# crypto\2024-12-12_06-32-08_LINKVNDC.png
# crypto\2024-12-12_06-44-12_ENSVNDC.png
# crypto\2024-12-12_06-45-12_XLMVNDC.png
# crypto\2024-12-12_06-45-16_HBARVNDC.png
# crypto\2024-12-12_06-48-06_SANDVNDC.png
# crypto\2024-12-12_06-56-06_GRASSVNDC.png
# crypto\2024-12-12_07-00-13_PEPE1000VNDC.png
# crypto\2024-12-12_07-10-24_JASMYVNDC.png
# crypto\2024-12-12_07-35-05_SANDVNDC.png
# crypto\2024-12-12_07-35-08_HBARVNDC.png
# crypto\2024-12-12_07-38-07_LYNXVNDC.png
# crypto\2024-12-12_07-55-06_JASMYVNDC.png
# crypto\2024-12-12_07-55-29_KSMVNDC.png
# crypto\2024-12-12_07-56-02_ADAVNDC.png
# crypto\2024-12-12_07-56-11_CKBVNDC.png
# crypto\2024-12-12_07-56-16_1000CATVNDC.png
# crypto\2024-12-12_07-56-19_SANDVNDC.png
# crypto\2024-12-12_07-56-47_OPVNDC.png
# crypto\2024-12-12_07-57-56_HBARVNDC.png
# crypto\2024-12-12_07-58-05_UXLINKVNDC.png
# crypto\2024-12-12_07-58-08_BIGTIMEVNDC.png
# crypto\2024-12-12_08-00-10_LYNXVNDC.png
# crypto\2024-12-12_08-17-05_NEIROVNDC.png
# crypto\2024-12-12_08-29-09_LINKVNDC.png
# crypto\2024-12-12_08-39-10_SUIVNDC.png
# crypto\2024-12-12_08-40-09_JASMYVNDC.png
# crypto\2024-12-12_08-40-18_TIAVNDC.png
# crypto\2024-12-12_08-42-27_CETUSVNDC.png
# crypto\2024-12-12_08-58-10_JASMYVNDC.png
# crypto\2024-12-12_08-58-18_LYNXVNDC.png
# crypto\2024-12-12_09-00-11_FOXYVNDC.png
# crypto\2024-12-12_09-47-04_CETUSVNDC.png
# crypto\2024-12-12_10-48-16_ADAVNDC.png
# crypto\2024-12-12_10-57-05_LISTAVNDC.png
# crypto\2024-12-12_11-05-50_CETUSVNDC.png
# crypto\2024-12-12_11-15-03_SUIVNDC.png
# crypto\2024-12-12_11-49-58_NEIROVNDC.png
# crypto\2024-12-12_11-55-18_MCAKEVNDC.png
# crypto\2024-12-12_11-56-11_GRASSVNDC.png
# crypto\2024-12-12_11-56-14_ADAVNDC.png
# crypto\2024-12-12_11-56-25_TRUVNDC.png
# crypto\2024-12-12_11-58-10_LYNXVNDC.png
# crypto\2024-12-12_11-59-26_XRPVNDC.png
# crypto\2024-12-12_11-59-46_PEPE1000VNDC.png
# crypto\2024-12-12_12-17-19_LYNXVNDC.png
# crypto\2024-12-12_12-27-33_GRASSVNDC.png
# crypto\2024-12-12_12-43-09_FOXYVNDC.png
# crypto\2024-12-12_12-56-17_XRPVNDC.png
# crypto\2024-12-12_12-56-18_WIFVNDC.png
# crypto\2024-12-12_12-56-30_CKBVNDC.png
# crypto\2024-12-12_12-57-04_JASMYVNDC.png
# crypto\2024-12-12_12-57-06_UXLINKVNDC.png
# crypto\2024-12-12_12-57-09_BIGTIMEVNDC.png
# crypto\2024-12-12_13-01-07_KSMVNDC.png
# crypto\2024-12-12_13-01-09_GRASSVNDC.png
# crypto\2024-12-12_13-24-37_UNIVNDC.png
# crypto\2024-12-12_13-25-18_AVAXVNDC.png
# crypto\2024-12-12_13-25-20_PEPE1000VNDC.png
# crypto\2024-12-12_14-00-16_LDOVNDC.png
# crypto\2024-12-12_14-05-20_MCAKEVNDC.png
# crypto\2024-12-12_14-15-10_LYNXVNDC.png
# crypto\2024-12-12_14-19-07_WLDVNDC.png
# crypto\2024-12-12_14-44-13_TRUVNDC.png
# crypto\2024-12-12_14-44-17_SANDVNDC.png
# crypto\2024-12-12_14-44-49_ENSVNDC.png
# crypto\2024-12-12_14-45-07_LYNXVNDC.png
# crypto\2024-12-12_14-45-09_PEPE1000VNDC.png
# crypto\2024-12-12_14-45-17_DOGEVNDC.png
# crypto\2024-12-12_14-46-14_WLDVNDC.png
# crypto\2024-12-12_14-47-03_LISTAVNDC.png
# crypto\2024-12-12_14-47-49_BIGTIMEVNDC.png
# crypto\2024-12-12_15-01-46_XRPVNDC.png
# crypto\2024-12-12_15-30-54_CETUSVNDC.png
# crypto\2024-12-12_15-43-06_HBARVNDC.png
# crypto\2024-12-12_15-47-57_XRPVNDC.png
# crypto\2024-12-12_16-00-08_MOODENGVNDC.png
# crypto\2024-12-12_16-01-59_CETUSVNDC.png
# crypto\2024-12-12_16-19-08_GRASSVNDC.png
# crypto\2024-12-12_16-27-13_LINKVNDC.png
# crypto\2024-12-12_16-38-19_MOODENGVNDC.png
# crypto\2024-12-12_16-41-19_1000CATVNDC.png
# crypto\2024-12-12_16-48-22_EDU3VNDC.png
# crypto\2024-12-12_16-48-40_TRUVNDC.png
# crypto\2024-12-12_16-48-46_TIAVNDC.png
# crypto\2024-12-12_16-49-35_GRASSVNDC.png
# crypto\2024-12-12_17-12-31_XRPVNDC.png
# crypto\2024-12-12_17-12-36_LDOVNDC.png
# crypto\2024-12-12_17-12-43_UNIVNDC.png
# crypto\2024-12-12_17-13-03_MIAVNDC.png
# crypto\2024-12-12_17-13-06_LINKVNDC.png
# crypto\2024-12-12_17-13-09_SANDVNDC.png
# crypto\2024-12-12_17-13-12_ADAVNDC.png
# crypto\2024-12-12_17-13-13_HBARVNDC.png
# crypto\2024-12-12_17-13-21_JASMYVNDC.png
# crypto\2024-12-12_17-13-26_TRUVNDC.png
# crypto\2024-12-12_17-13-45_DOTVNDC.png
# crypto\2024-12-12_17-14-12_SXPVNDC.png
# crypto\2024-12-12_17-14-15_EDU3VNDC.png
# crypto\2024-12-12_17-14-22_XLMVNDC.png
# crypto\2024-12-12_17-14-26_PEPE1000VNDC.png
# crypto\2024-12-12_17-14-36_CKBVNDC.png
# crypto\2024-12-12_17-14-38_MOODENGVNDC.png
# crypto\2024-12-12_17-15-09_SOLVNDC.png
# crypto\2024-12-12_17-15-14_FOXYVNDC.png
# crypto\2024-12-12_17-15-16_WIFVNDC.png
# crypto\2024-12-12_17-15-19_LYNXVNDC.png
# crypto\2024-12-12_17-15-21_AVAXVNDC.png
# crypto\2024-12-12_17-15-23_WLDVNDC.png
# crypto\2024-12-12_17-15-32_EGPT1000VNDC.png
# crypto\2024-12-12_17-15-35_BIGTIMEVNDC.png
# crypto\2024-12-12_17-15-37_OPVNDC.png
# crypto\2024-12-12_17-57-20_BIGTIMEVNDC.png
# crypto\2024-12-12_17-58-08_TRUVNDC.png
# crypto\2024-12-12_17-58-22_CKBVNDC.png
# crypto\2024-12-12_17-58-24_UXLINKVNDC.png
# crypto\2024-12-12_18-20-51_DOGSVNDC.png
# crypto\2024-12-12_18-41-36_AVAXVNDC.png
# crypto\2024-12-12_18-42-03_MIAVNDC.png
# crypto\2024-12-12_18-42-04_MEON1000VNDC.png
# crypto\2024-12-12_18-42-06_TRUVNDC.png
# crypto\2024-12-12_18-42-11_LISTAVNDC.png
# crypto\2024-12-12_18-42-38_EDU3VNDC.png
# crypto\2024-12-12_18-42-59_NEIROVNDC.png
# crypto\2024-12-12_18-43-11_EGPT1000VNDC.png
# crypto\2024-12-12_18-43-15_OPVNDC.png
# crypto\2024-12-12_18-43-17_KSMVNDC.png
# crypto\2024-12-12_18-43-31_DOGSVNDC.png
# crypto\2024-12-12_18-44-05_FOXYVNDC.png
# crypto\2024-12-12_18-46-11_CETUSVNDC.png
# crypto\2024-12-12_18-47-05_LINKVNDC.png
# crypto\2024-12-12_19-34-11_LINKVNDC.png
# crypto\2024-12-12_19-48-14_SUIVNDC.png
# crypto\2024-12-12_20-11-16_LYNXVNDC.png
# crypto\2024-12-12_20-42-25_LYNXVNDC.png
# crypto\2024-12-12_20-44-52_ADAVNDC.png
# crypto\2024-12-12_20-45-06_NEIROVNDC.png
# crypto\2024-12-12_20-45-49_DOGEVNDC.png
# crypto\2024-12-12_20-45-58_AVAXVNDC.png
# crypto\2024-12-12_20-45-59_WLDVNDC.png
# crypto\2024-12-12_20-54-07_MEON1000VNDC.png
# crypto\2024-12-12_20-56-05_TRUVNDC.png
# crypto\2024-12-12_20-56-10_TIAVNDC.png
# crypto\2024-12-12_20-57-10_FOXYVNDC.png
# crypto\2024-12-12_21-40-45_CETUSVNDC.png
# crypto\2024-12-12_21-43-53_PEPE1000VNDC.png
# crypto\2024-12-12_22-18-19_UNIVNDC.png
# crypto\2024-12-12_22-19-09_DOGEVNDC.png
# crypto\2024-12-12_22-19-09_JASMYVNDC.png
# crypto\2024-12-12_22-19-10_MCAKEVNDC.png
# crypto\2024-12-12_22-19-10_SXPVNDC.png
# crypto\2024-12-12_22-19-11_EGPT1000VNDC.png
# crypto\2024-12-12_22-19-12_MEON1000VNDC.png
# crypto\2024-12-12_22-19-12_DOGSVNDC.png
# crypto\2024-12-12_22-19-13_FOXYVNDC.png
# crypto\2024-12-12_22-19-14_OPVNDC.png
# crypto\2024-12-12_22-19-15_NEIROVNDC.png
# crypto\2024-12-12_22-19-16_SANDVNDC.png
# crypto\2024-12-12_22-19-18_PEPE1000VNDC.png
# crypto\2024-12-12_22-19-18_WLDVNDC.png
# crypto\2024-12-12_22-19-27_MIAVNDC.png
# crypto\2024-12-12_22-19-30_TRUVNDC.png
# crypto\2024-12-12_22-19-31_XRPVNDC.png
# crypto\2024-12-12_22-19-31_WIFVNDC.png
# crypto\2024-12-12_22-19-42_SOLVNDC.png
# crypto\2024-12-12_22-19-50_LYNXVNDC.png
# crypto\2024-12-12_22-20-18_SUIVNDC.png
# crypto\2024-12-12_22-21-08_XLMVNDC.png
# crypto\2024-12-12_22-21-09_DOTVNDC.png
# crypto\2024-12-12_22-21-12_HBARVNDC.png
# crypto\2024-12-12_22-21-20_UXLINKVNDC.png
# crypto\2024-12-12_22-39-18_TIAVNDC.png
# crypto\2024-12-12_22-40-03_TRUVNDC.png
# crypto\2024-12-12_22-40-06_SANDVNDC.png
# crypto\2024-12-12_22-42-42_CETUSVNDC.png
# crypto\2024-12-12_22-58-46_UNIVNDC.png
# crypto\2024-12-12_22-59-13_GRASSVNDC.png
# crypto\2024-12-12_23-25-15_JASMYVNDC.png
# crypto\2024-12-12_23-34-15_LINKVNDC.png
# crypto\2024-12-12_23-34-18_PEPE1000VNDC.png
# crypto\2024-12-12_23-36-06_OPVNDC.png
# crypto\2024-12-12_23-38-20_GRASSVNDC.png
# crypto\2024-12-12_23-41-14_LYNXVNDC.png
# crypto\2024-12-13_00-30-07_JASMYVNDC.png
# crypto\2024-12-13_00-30-16_HBARVNDC.png
# crypto\2024-12-13_00-30-45_KSMVNDC.png
# crypto\2024-12-13_00-30-46_ENSVNDC.png
# crypto\2024-12-13_00-31-02_SANDVNDC.png
# crypto\2024-12-13_00-31-15_XRPVNDC.png
# crypto\2024-12-13_00-31-26_DOGEVNDC.png
# crypto\2024-12-13_01-20-33_LDOVNDC.png
# crypto\2024-12-13_01-20-43_TRUVNDC.png
# crypto\2024-12-13_01-24-19_GRASSVNDC.png
# crypto\2024-12-13_01-26-06_DOGSVNDC.png
# crypto\2024-12-13_01-42-13_EGPT1000VNDC.png
# crypto\2024-12-13_01-42-18_ENSVNDC.png
# crypto\2024-12-13_01-42-46_MEON1000VNDC.png
# crypto\2024-12-13_01-43-05_DOTVNDC.png
# crypto\2024-12-13_01-43-07_WLDVNDC.png
# crypto\2024-12-13_01-43-38_TIAVNDC.png
# crypto\2024-12-13_01-44-05_XRPVNDC.png
# crypto\2024-12-13_01-44-06_XLMVNDC.png
# crypto\2024-12-13_01-44-36_BIGTIMEVNDC.png
# crypto\2024-12-13_01-44-55_SANDVNDC.png
# crypto\2024-12-13_01-45-08_LINKVNDC.png
# crypto\2024-12-13_01-45-12_PEPE1000VNDC.png
# crypto\2024-12-13_01-45-19_SOLVNDC.png
# crypto\2024-12-13_01-45-49_DOGEVNDC.png
# crypto\2024-12-13_01-46-12_LYNXVNDC.png
# crypto\2024-12-13_02-21-11_UXLINKVNDC.png
# crypto\2024-12-13_02-47-33_LYNXVNDC.png
# crypto\2024-12-13_02-48-17_1000CATVNDC.png
# crypto\2024-12-13_03-03-08_PEPE1000VNDC.png
# crypto\2024-12-13_03-28-45_JASMYVNDC.png
# crypto\2024-12-13_04-46-42_HBARVNDC.png
# crypto\2024-12-13_04-47-05_JASMYVNDC.png
# crypto\2024-12-13_04-47-06_SXPVNDC.png
# crypto\2024-12-13_04-47-07_MIAVNDC.png
# crypto\2024-12-13_04-47-08_SUIVNDC.png
# crypto\2024-12-13_04-47-09_TRUVNDC.png
# crypto\2024-12-13_04-47-10_XRPVNDC.png
# crypto\2024-12-13_04-47-10_WIFVNDC.png
# crypto\2024-12-13_04-47-11_KSMVNDC.png
# crypto\2024-12-13_04-47-11_DOTVNDC.png
# crypto\2024-12-13_04-47-12_GRASSVNDC.png
# crypto\2024-12-13_04-47-13_AVAXVNDC.png
# crypto\2024-12-13_04-47-13_LISTAVNDC.png
# crypto\2024-12-13_04-47-13_TIAVNDC.png
# crypto\2024-12-13_04-47-13_PEPE1000VNDC.png
# crypto\2024-12-13_04-47-14_ADAVNDC.png
# crypto\2024-12-13_04-47-26_NEIROVNDC.png
# crypto\2024-12-13_04-47-57_XLMVNDC.png
# crypto\2024-12-13_04-48-05_UNIVNDC.png
# crypto\2024-12-13_04-48-06_DOGEVNDC.png
# crypto\2024-12-13_04-48-07_UXLINKVNDC.png
# crypto\2024-12-13_04-48-08_MOODENGVNDC.png
# crypto\2024-12-13_04-48-08_EDU3VNDC.png
# crypto\2024-12-13_04-48-09_MEON1000VNDC.png
# crypto\2024-12-13_04-48-09_FOXYVNDC.png
# crypto\2024-12-13_04-48-11_1000CATVNDC.png
# crypto\2024-12-13_04-48-13_SANDVNDC.png
# crypto\2024-12-13_04-48-15_WLDVNDC.png
# crypto\2024-12-13_04-48-54_EGPT1000VNDC.png
# crypto\2024-12-13_04-49-08_CETUSVNDC.png
# crypto\2024-12-13_04-50-04_LDOVNDC.png
# crypto\2024-12-13_05-16-08_LINKVNDC.png
# crypto\2024-12-13_05-16-08_1000CATVNDC.png
# crypto\2024-12-13_05-16-19_SOLVNDC.png
# crypto\2024-12-13_05-16-50_JASMYVNDC.png
# crypto\2024-12-13_05-19-18_LYNXVNDC.png
# crypto\2024-12-13_06-28-13_MOODENGVNDC.png
# crypto\2024-12-13_06-28-39_LINKVNDC.png
# crypto\2024-12-13_06-29-07_SXPVNDC.png
# crypto\2024-12-13_06-29-31_WLDVNDC.png
# crypto\2024-12-13_06-30-11_MIAVNDC.png
# crypto\2024-12-13_06-30-18_LISTAVNDC.png
# crypto\2024-12-13_07-21-06_CETUSVNDC.png
# crypto\2024-12-13_07-40-16_HBARVNDC.png
# crypto\2024-12-13_07-55-09_SANDVNDC.png
# crypto\2024-12-13_07-56-14_AVAXVNDC.png
# crypto\2024-12-13_08-00-05_CETUSVNDC.png
# crypto\2024-12-13_08-08-10_SXPVNDC.png
# crypto\2024-12-13_08-08-30_LINKVNDC.png
# crypto\2024-12-13_08-08-45_FOXYVNDC.png
# crypto\2024-12-13_08-09-14_GRASSVNDC.png
# crypto\2024-12-13_08-09-22_UNIVNDC.png
# crypto\2024-12-13_08-09-24_SOLVNDC.png
# crypto\2024-12-13_08-10-09_BIGTIMEVNDC.png
# crypto\2024-12-13_08-10-12_KSMVNDC.png
# crypto\2024-12-13_08-10-14_DOTVNDC.png
# crypto\2024-12-13_08-10-16_LISTAVNDC.png
# crypto\2024-12-13_08-11-18_SANDVNDC.png
# crypto\2024-12-13_08-26-17_LDOVNDC.png
# crypto\2024-12-13_08-27-03_XRPVNDC.png
# crypto\2024-12-13_08-27-05_NEIROVNDC.png
# crypto\2024-12-13_08-27-06_XLMVNDC.png
# crypto\2024-12-13_08-27-07_KSMVNDC.png
# crypto\2024-12-13_08-27-08_DOTVNDC.png
# crypto\2024-12-13_08-27-09_ENSVNDC.png
# crypto\2024-12-13_08-27-11_SANDVNDC.png
# crypto\2024-12-13_08-27-12_LYNXVNDC.png
# crypto\2024-12-13_08-27-13_AVAXVNDC.png
# crypto\2024-12-13_08-27-15_PEPE1000VNDC.png
# crypto\2024-12-13_08-27-16_WLDVNDC.png
# crypto\2024-12-13_08-27-23_CETUSVNDC.png
# crypto\2024-12-13_08-27-24_DOGEVNDC.png
# crypto\2024-12-13_08-27-25_JASMYVNDC.png
# crypto\2024-12-13_08-27-26_SOLVNDC.png
# crypto\2024-12-13_08-27-27_MCAKEVNDC.png
# crypto\2024-12-13_08-27-29_CKBVNDC.png
# crypto\2024-12-13_08-27-30_EGPT1000VNDC.png
# crypto\2024-12-13_08-27-31_MIAVNDC.png
# crypto\2024-12-13_08-27-33_MEON1000VNDC.png
# crypto\2024-12-13_08-27-35_TRUVNDC.png
# crypto\2024-12-13_08-27-36_OPVNDC.png
# crypto\2024-12-13_08-27-38_WIFVNDC.png
# crypto\2024-12-13_08-27-43_ADAVNDC.png
# crypto\2024-12-13_08-27-53_EDU3VNDC.png
# crypto\2024-12-13_08-28-06_UNIVNDC.png
# crypto\2024-12-13_08-28-09_SXPVNDC.png
# crypto\2024-12-13_08-28-11_MOODENGVNDC.png
# crypto\2024-12-13_08-28-13_FOXYVNDC.png
# crypto\2024-12-13_08-28-16_1000CATVNDC.png
# crypto\2024-12-13_08-28-19_LISTAVNDC.png
# crypto\2024-12-13_08-28-20_TIAVNDC.png
# crypto\2024-12-13_08-29-04_BIGTIMEVNDC.png
# crypto\2024-12-13_08-29-19_UXLINKVNDC.png
# crypto\2024-12-13_09-50-05_SUIVNDC.png
# crypto\2024-12-13_10-02-09_UNIVNDC.png
# crypto\2024-12-13_10-02-11_JASMYVNDC.png
# crypto\2024-12-13_10-02-12_SXPVNDC.png
# crypto\2024-12-13_10-02-13_CKBVNDC.png
# crypto\2024-12-13_10-02-15_MIAVNDC.png
# crypto\2024-12-13_10-02-18_FOXYVNDC.png
# crypto\2024-12-13_10-02-19_BIGTIMEVNDC.png
# crypto\2024-12-13_10-02-23_SANDVNDC.png
# crypto\2024-12-13_10-02-26_ADAVNDC.png
# crypto\2024-12-13_10-02-42_TIAVNDC.png
# crypto\2024-12-13_10-02-44_WLDVNDC.png
# crypto\2024-12-13_10-03-01_PEPE1000VNDC.png
# crypto\2024-12-13_10-03-08_CETUSVNDC.png
# crypto\2024-12-13_10-06-21_LINKVNDC.png
# crypto\2024-12-13_10-24-33_ENSVNDC.png
# crypto\2024-12-13_10-32-12_DOTVNDC.png
# crypto\2024-12-13_10-32-26_BIGTIMEVNDC.png
# crypto\2024-12-13_11-00-17_UNIVNDC.png
# crypto\2024-12-13_11-02-20_LDOVNDC.png
# crypto\2024-12-13_11-12-15_SUIVNDC.png
# crypto\2024-12-13_11-13-19_MOODENGVNDC.png
# crypto\2024-12-13_11-15-19_GRASSVNDC.png
# crypto\2024-12-13_11-15-22_PEPE1000VNDC.png
# crypto\2024-12-13_11-27-13_BIGTIMEVNDC.png
# crypto\2024-12-13_11-28-00_MEON1000VNDC.png
# crypto\2024-12-13_11-28-32_MOODENGVNDC.png
# crypto\2024-12-13_11-29-20_EGPT1000VNDC.png
# crypto\2024-12-13_11-39-19_UNIVNDC.png
# crypto\2024-12-13_11-40-14_TRUVNDC.png
# crypto\2024-12-13_11-40-15_LINKVNDC.png
# crypto\2024-12-13_11-41-07_GRASSVNDC.png
# crypto\2024-12-13_12-08-10_LDOVNDC.png
# crypto\2024-12-13_12-10-15_LINKVNDC.png
# crypto\2024-12-13_12-34-57_OPVNDC.png
# crypto\2024-12-13_12-35-03_LDOVNDC.png
# crypto\2024-12-13_12-37-29_AVAXVNDC.png
# crypto\2024-12-13_12-37-41_FOXYVNDC.png
# crypto\2024-12-13_12-37-45_ENSVNDC.png
# crypto\2024-12-13_13-31-04_GRASSVNDC.png
# crypto\2024-12-13_13-46-02_WLDVNDC.png
# crypto\2024-12-13_13-46-11_EGPT1000VNDC.png
# crypto\2024-12-13_13-46-13_MIAVNDC.png
# crypto\2024-12-13_13-46-16_BIGTIMEVNDC.png
# crypto\2024-12-13_13-46-18_WIFVNDC.png
# crypto\2024-12-13_13-46-19_XLMVNDC.png
# crypto\2024-12-13_13-46-21_KSMVNDC.png
# crypto\2024-12-13_13-46-22_SANDVNDC.png
# crypto\2024-12-13_13-46-24_AVAXVNDC.png
# crypto\2024-12-13_13-46-26_PEPE1000VNDC.png
# crypto\2024-12-13_13-46-41_DOTVNDC.png
# crypto\2024-12-13_13-46-54_EDU3VNDC.png
# crypto\2024-12-13_13-46-56_DOGSVNDC.png
# crypto\2024-12-13_13-46-57_TRUVNDC.png
# crypto\2024-12-13_13-47-03_TIAVNDC.png
# crypto\2024-12-13_13-47-05_ADAVNDC.png
# crypto\2024-12-13_13-47-13_MCAKEVNDC.png
# crypto\2024-12-13_13-47-14_SXPVNDC.png
# crypto\2024-12-13_13-47-15_CKBVNDC.png
# crypto\2024-12-13_13-47-17_MEON1000VNDC.png
# crypto\2024-12-13_13-47-21_NEIROVNDC.png
# crypto\2024-12-13_13-47-34_UXLINKVNDC.png
# crypto\2024-12-13_13-49-28_HBARVNDC.png
# crypto\2024-12-13_13-49-34_UNIVNDC.png
# crypto\2024-12-13_14-11-19_ENSVNDC.png
# crypto\2024-12-13_14-11-28_UNIVNDC.png
# crypto\2024-12-13_14-12-09_KSMVNDC.png
# crypto\2024-12-13_14-12-20_SXPVNDC.png
# crypto\2024-12-13_14-12-25_XRPVNDC.png
# crypto\2024-12-13_14-12-45_AVAXVNDC.png
# crypto\2024-12-13_14-14-26_TIAVNDC.png
# crypto\2024-12-13_14-14-39_LINKVNDC.png
# crypto\2024-12-13_16-18-10_LDOVNDC.png
# crypto\2024-12-13_16-42-59_BIGTIMEVNDC.png
# crypto\2024-12-13_16-43-04_LISTAVNDC.png
# crypto\2024-12-13_16-43-15_EGPT1000VNDC.png
# crypto\2024-12-13_16-43-17_DOGSVNDC.png
# crypto\2024-12-13_16-43-21_WIFVNDC.png
# crypto\2024-12-13_16-43-26_LDOVNDC.png
# crypto\2024-12-13_16-43-35_MIAVNDC.png
# crypto\2024-12-13_16-44-15_MCAKEVNDC.png
# crypto\2024-12-13_16-44-35_SXPVNDC.png
# crypto\2024-12-13_17-30-08_HBARVNDC.png
# crypto\2024-12-13_17-31-05_MOODENGVNDC.png
# crypto\2024-12-13_17-31-21_MCAKEVNDC.png
# crypto\2024-12-13_17-32-02_CETUSVNDC.png
# crypto\2024-12-13_17-32-03_DOGEVNDC.png
# crypto\2024-12-13_17-32-06_UXLINKVNDC.png
# crypto\2024-12-13_17-32-10_TRUVNDC.png
# crypto\2024-12-13_17-32-15_LISTAVNDC.png
# crypto\2024-12-13_17-32-17_ADAVNDC.png
# crypto\2024-12-13_17-32-25_JASMYVNDC.png
# crypto\2024-12-13_17-32-32_NEIROVNDC.png
# crypto\2024-12-13_17-32-49_XLMVNDC.png
# crypto\2024-12-13_17-32-50_DOTVNDC.png
# crypto\2024-12-13_17-33-06_1000CATVNDC.png
# crypto\2024-12-13_17-33-11_PEPE1000VNDC.png
# crypto\2024-12-13_17-34-46_GRASSVNDC.png
# crypto\2024-12-13_18-17-14_GRASSVNDC.png
# crypto\2024-12-13_18-42-50_CETUSVNDC.png
# crypto\2024-12-13_18-44-08_LINKVNDC.png
# crypto\2024-12-13_18-49-34_LDOVNDC.png
# crypto\2024-12-13_18-57-08_EGPT1000VNDC.png
# crypto\2024-12-13_18-57-25_MEON1000VNDC.png
# crypto\2024-12-13_19-35-25_CETUSVNDC.png
# crypto\2024-12-13_19-35-30_SUIVNDC.png
# crypto\2024-12-13_19-40-25_UXLINKVNDC.png
# crypto\2024-12-13_19-43-27_MOODENGVNDC.png
# crypto\2024-12-13_19-44-31_JASMYVNDC.png
# crypto\2024-12-13_19-52-50_HBARVNDC.png
# crypto\2024-12-13_19-56-09_LYNXVNDC.png
# crypto\2024-12-13_20-12-10_HBARVNDC.png
# crypto\2024-12-13_21-06-15_HBARVNDC.png
# crypto\2024-12-13_21-23-49_SUIVNDC.png
# crypto\2024-12-13_21-26-11_CETUSVNDC.png
# crypto\2024-12-13_22-32-47_HBARVNDC.png
# crypto\2024-12-13_22-41-50_SUIVNDC.png
# crypto\2024-12-13_23-01-19_MCAKEVNDC.png
# crypto\2024-12-13_23-01-58_FOXYVNDC.png
# crypto\2024-12-13_23-02-04_LYNXVNDC.png
# crypto\2024-12-13_23-02-06_PEPE1000VNDC.png
# crypto\2024-12-13_23-02-14_JASMYVNDC.png
# crypto\2024-12-13_23-02-19_BIGTIMEVNDC.png
# crypto\2024-12-13_23-02-21_OPVNDC.png
# crypto\2024-12-13_23-02-23_1000CATVNDC.png
# crypto\2024-12-13_23-02-28_WLDVNDC.png
# crypto\2024-12-13_23-02-37_SOLVNDC.png
# crypto\2024-12-13_23-02-42_TRUVNDC.png
# crypto\2024-12-13_23-39-51_LYNXVNDC.png
# crypto\2024-12-14_00-02-04_NEIROVNDC.png
# crypto\2024-12-14_00-02-15_UNIVNDC.png
# crypto\2024-12-14_00-02-17_CETUSVNDC.png
# crypto\2024-12-14_00-02-19_MCAKEVNDC.png
# crypto\2024-12-14_00-02-22_EDU3VNDC.png
# crypto\2024-12-14_00-02-39_MOODENGVNDC.png
# crypto\2024-12-14_00-03-04_ADAVNDC.png
# crypto\2024-12-14_00-03-14_EGPT1000VNDC.png
# crypto\2024-12-14_00-03-16_MEON1000VNDC.png
# crypto\2024-12-14_00-03-25_LDOVNDC.png
# crypto\2024-12-14_00-03-36_FOXYVNDC.png
# crypto\2024-12-14_00-08-08_AVAXVNDC.png
# crypto\2024-12-14_00-25-16_JASMYVNDC.png
# crypto\2024-12-14_00-26-05_KSMVNDC.png
# crypto\2024-12-14_01-41-09_CETUSVNDC.png
# crypto\2024-12-14_01-54-24_LDOVNDC.png
# crypto\2024-12-14_01-55-11_KSMVNDC.png
# crypto\2024-12-14_01-55-14_TIAVNDC.png
# crypto\2024-12-14_01-57-12_MIAVNDC.png
# crypto\2024-12-14_01-57-26_UNIVNDC.png
# crypto\2024-12-14_01-58-17_CETUSVNDC.png
# crypto\2024-12-14_01-58-20_CKBVNDC.png
# crypto\2024-12-14_02-00-18_EDU3VNDC.png
# crypto\2024-12-14_02-00-25_ADAVNDC.png
# crypto\2024-12-14_02-01-07_UXLINKVNDC.png
# crypto\2024-12-14_02-10-15_XRPVNDC.png
# crypto\2024-12-14_02-44-34_TRUVNDC.png
# crypto\2024-12-14_04-00-03_FOXYVNDC.png
# crypto\2024-12-14_05-13-04_HBARVNDC.png
# crypto\2024-12-14_05-17-42_LDOVNDC.png
# crypto\2024-12-14_05-18-15_EGPT1000VNDC.png
# crypto\2024-12-14_05-18-16_UXLINKVNDC.png
# crypto\2024-12-14_05-18-18_MEON1000VNDC.png
# crypto\2024-12-14_05-19-05_TIAVNDC.png
# crypto\2024-12-14_05-25-05_GRASSVNDC.png
# crypto\2024-12-14_06-00-15_PEPE1000VNDC.png
# crypto\2024-12-14_07-15-04_JASMYVNDC.png
# crypto\2024-12-14_07-18-36_MOODENGVNDC.png
# crypto\2024-12-14_07-39-14_BIGTIMEVNDC.png
# crypto\2024-12-14_07-45-16_FOXYVNDC.png
# crypto\2024-12-14_08-00-13_HBARVNDC.png
# crypto\2024-12-14_08-41-10_JASMYVNDC.png
# crypto\2024-12-14_08-42-36_MOODENGVNDC.png
# crypto\2024-12-14_09-08-36_ENSVNDC.png
# crypto\2024-12-14_09-09-14_HBARVNDC.png
# crypto\2024-12-14_09-09-16_LDOVNDC.png
# crypto\2024-12-14_09-10-22_GRASSVNDC.png
# crypto\2024-12-14_09-18-06_FOXYVNDC.png
# crypto\2024-12-14_09-18-08_TRUVNDC.png
# crypto\2024-12-14_09-18-21_UNIVNDC.png
# crypto\2024-12-14_09-19-13_JASMYVNDC.png
# crypto\2024-12-14_09-20-22_MEON1000VNDC.png
# crypto\2024-12-14_09-45-29_LINKVNDC.png
# crypto\2024-12-14_09-47-17_UXLINKVNDC.png
# crypto\2024-12-14_10-03-26_WIFVNDC.png
# crypto\2024-12-14_10-35-06_UNIVNDC.png
# crypto\2024-12-14_10-48-18_MOODENGVNDC.png
# crypto\2024-12-14_11-17-15_CETUSVNDC.png
# crypto\2024-12-14_11-18-14_SANDVNDC.png
# crypto\2024-12-14_11-20-43_NEIROVNDC.png
# crypto\2024-12-14_11-43-59_UXLINKVNDC.png
# crypto\2024-12-14_12-03-30_LINKVNDC.png
# crypto\2024-12-14_12-52-11_UXLINKVNDC.png
# crypto\2024-12-14_13-23-17_LDOVNDC.png
# crypto\2024-12-14_13-40-11_ADAVNDC.png
# crypto\2024-12-14_13-44-25_XLMVNDC.png
# crypto\2024-12-14_15-17-12_FOXYVNDC.png
# crypto\2024-12-14_15-30-08_XRPVNDC.png
# crypto\2024-12-14_16-02-14_GRASSVNDC.png
# crypto\2024-12-14_16-10-35_CKBVNDC.png
# crypto\2024-12-14_16-12-18_DOGSVNDC.png
# crypto\2024-12-14_16-18-12_SUIVNDC.png
# crypto\2024-12-14_16-18-28_EDU3VNDC.png
# crypto\2024-12-14_16-19-48_CETUSVNDC.png
# crypto\2024-12-14_16-45-04_ENSVNDC.png
# crypto\2024-12-14_17-01-43_SUIVNDC.png
# crypto\2024-12-14_17-08-15_FOXYVNDC.png
# crypto\2024-12-14_17-11-15_MEON1000VNDC.png
# crypto\2024-12-14_17-11-20_ENSVNDC.png
# crypto\2024-12-14_17-12-08_OPVNDC.png
# crypto\2024-12-14_17-12-09_XRPVNDC.png
# crypto\2024-12-14_17-12-22_SXPVNDC.png
# crypto\2024-12-14_17-12-28_XLMVNDC.png
# crypto\2024-12-14_17-14-28_LDOVNDC.png
# crypto\2024-12-14_17-26-19_LISTAVNDC.png
# crypto\2024-12-14_17-27-06_DOTVNDC.png
# crypto\2024-12-14_17-27-33_SXPVNDC.png
